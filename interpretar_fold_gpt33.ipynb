# %%
# %%bash
# # Bucle para los folds 2 a 5 (Fold 1 ya lo hiciste)
# for fold in {1..5}; do
#   echo "--- Procesando Fold $fold ---"
#
#   # 1. Calcular SHAP
#   python interpretar_fold_gpt.py shap \
#     --run_dir ./resultados33 --fold $fold --clf xgb \
#     --global_tensor_path /home/diego/Escritorio/limpio/AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned/GLOBAL_TENSOR_from_AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned.npz \
#     --metadata_path /home/diego/Escritorio/limpio/SubjectsData_AAL3_procesado2.csv \
#     --channels_to_use 1 4 \
#     --latent_dim 256 \
#     --latent_features_type mu \
#     --metadata_features Age Sex Manufacturer \
#     --num_conv_layers_encoder 4 \
#     --decoder_type convtranspose \
#     --dropout_rate_vae 0.25 \
#     --use_layernorm_vae_fc \
#     --intermediate_fc_dim_vae half \
#     --vae_final_activation linear \
#     --gn_num_groups 16
#
#   # 2. Generar Saliencia
#   python interpretar_fold_gpt.py saliency \
#     --run_dir ./resultados33 --fold $fold --clf xgb \
#     --global_tensor_path /home/diego/Escritorio/limpio/AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned/GLOBAL_TENSOR_from_AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned.npz \
#     --metadata_path /home/diego/Escritorio/limpio/SubjectsData_AAL3_procesado2.csv \
#     --roi_annotation_path /home/diego/Escritorio/limpio/roi_info_master.csv \
#     --roi_order_path /home/diego/Escritorio/limpio/roi_order_131.npy \
#     --channels_to_use 1 4 \
#     --latent_dim 256 \
#     --top_k 50 \
#     --shap_weight_mode ad_vs_cn_diff \
#     --decoder_type convtranspose \
#     --dropout_rate_vae 0.25 \
#     --use_layernorm_vae_fc \
#     --intermediate_fc_dim_vae half \
#     --vae_final_activation linear \
#     --gn_num_groups 16 \
#     --num_conv_layers_encoder 4
#
# done
#
# echo "✅ ¡Análisis de interpretabilidad para todos los folds completado!"
# Out:
# --- Procesando Fold 1 ---
# [INFO] [SHAP] fold=1 clf=xgb
# [INFO] [SHAP] Cargando datos de background CRUDOS desde: shap_background_raw_xgb.joblib
# [INFO] [SHAP] X_raw shape=(37, 259) (latentes + 3 metadatos)
# [INFO] [SHAP] Background DataFrame detectado pero columnas no coinciden; transformando…
# [INFO] [SHAP] Pack guardado: resultados33/fold_1/interpretability_shap/shap_pack_xgb.joblib
# [INFO] [SALIENCY] fold=1 clf=xgb  (pack cargado: shap_pack_xgb.joblib)
# [INFO] Usando ROI order de resultados33/roi_order_131.joblib.
# [INFO] Cargado fichero de anotaciones: /home/diego/Escritorio/limpio/roi_info_master.csv
# [INFO] [SALIENCY] 50 latentes ponderadas. Ejemplo:
#  latent_idx    weight  importance            feature
#         219  0.142980    0.095122 latent__latent_219
#         126 -0.121341   -0.080726 latent__latent_126
#         103  0.086473    0.057529 latent__latent_103
#         184  0.066897    0.044506 latent__latent_184
#         139  0.054078    0.035977 latent__latent_139
# [INFO] [SALIENCY] Sujetos AD=19  CN=18
# [INFO] [SALIENCY] Ranking de conexiones ANOTADO guardado: resultados33/fold_1/interpretability_xgb/ranking_conexiones_ANOTADO_top50.csv
# [INFO] Top 20 conexiones anotadas:
#       Rank src_AAL3_Name dst_AAL3_Name  Saliency_Score          src_Refined_Network          dst_Refined_Network
# 8026     1         CER6R        CER10R       -0.000221            Visual_Peripheral                   Cerebellum
# 2569     2          FMOR          LPCR       -0.000184     DefaultMode_DorsalMedial                Somatomotor_A
# 1708     3           ORR          VER6        0.000175                Somatomotor_B            Visual_Peripheral
# 7823     4      CERCRU2R         CER9R       -0.000173                   Cerebellum                   Cerebellum
# 7828     5      CERCRU2R          VER6        0.000173                   Cerebellum            Visual_Peripheral
# 2971     6       OFCMEDR            QR       -0.000171                 Limbic_B_OFC               Visual_Central
# 1939     7          SMAR          VER6        0.000164                Somatomotor_A            Visual_Peripheral
# 1163     8          F3TR        HIPPOR        0.000162                    Control_A            Limbic_A_TempPole
# 3390     9      OFCPOSTR         FUSIL        0.000161                 Limbic_B_OFC            Visual_Peripheral
# 2333    10           FMR           O3L        0.000159     DefaultMode_DorsalMedial            Visual_Peripheral
# 4338    11        HIPPOR         LINGR        0.000154            Limbic_A_TempPole               Visual_Central
# 1941    12          SMAR          VER8        0.000152                Somatomotor_A       Background/NonCortical
# 1872    13          SMAR        AMYGDR        0.000152                Somatomotor_A            Limbic_A_TempPole
# 2121    14          COBR          GSMR       -0.000151                 Limbic_B_OFC  Salience_VentralAttention_A
# 5780    15         FUSIL       CER4_5R       -0.000151            Visual_Peripheral               Visual_Central
# 6985    16           NLR          T2AL        0.000150  Salience_VentralAttention_A            Limbic_A_TempPole
# 2981    17       OFCMEDR         FUSIR       -0.000150                 Limbic_B_OFC            Visual_Peripheral
# 5553    18           O2R         CER3R       -0.000144            Visual_Peripheral             DefaultMode_Core
# 3011    19       OFCMEDR          T2AR       -0.000141                 Limbic_B_OFC            Limbic_A_TempPole
# 1942    20          SMAR          VER9        0.000140                Somatomotor_A       Background/NonCortical
# [INFO] [SALIENCY] Completo. Resultados en resultados33/fold_1/interpretability_xgb
# --- Procesando Fold 2 ---
# [INFO] [SHAP] fold=2 clf=xgb
# [INFO] [SHAP] Cargando datos de background CRUDOS desde: shap_background_raw_xgb.joblib
# [INFO] [SHAP] X_raw shape=(37, 259) (latentes + 3 metadatos)
# [INFO] [SHAP] Background DataFrame detectado pero columnas no coinciden; transformando…
# [INFO] [SHAP] Pack guardado: resultados33/fold_2/interpretability_shap/shap_pack_xgb.joblib
# [INFO] [SALIENCY] fold=2 clf=xgb  (pack cargado: shap_pack_xgb.joblib)
# [INFO] Usando ROI order de resultados33/roi_order_131.joblib.
# [INFO] Cargado fichero de anotaciones: /home/diego/Escritorio/limpio/roi_info_master.csv
# [INFO] [SALIENCY] 50 latentes ponderadas. Ejemplo:
#  latent_idx    weight  importance            feature
#           2  0.076257    0.116420   latent__latent_2
#         137  0.056836    0.086770 latent__latent_137
#         140  0.051967    0.079337 latent__latent_140
#         127 -0.049336   -0.075320 latent__latent_127
#         252  0.046813    0.071469 latent__latent_252
# [INFO] [SALIENCY] Sujetos AD=19  CN=18
# [INFO] [SALIENCY] Ranking de conexiones ANOTADO guardado: resultados33/fold_2/interpretability_xgb/ranking_conexiones_ANOTADO_top50.csv
# [INFO] Top 20 conexiones anotadas:
#       Rank src_AAL3_Name dst_AAL3_Name  Saliency_Score          src_Refined_Network          dst_Refined_Network
# 6115     1           P1R         PALLR        0.000160            DorsalAttention_A                Basal_Ganglia
# 3139     2       OFCANTL          VER7       -0.000159                 Limbic_B_OFC       Background/NonCortical
# 2524     3          FMOR       OFCANTL       -0.000155     DefaultMode_DorsalMedial                 Limbic_B_OFC
# 7303     4           T1R         CER3R        0.000145             DefaultMode_Temp             DefaultMode_Core
# 2300     5           FMR          FMOR       -0.000145     DefaultMode_DorsalMedial     DefaultMode_DorsalMedial
# 7008     6           NLR        VER4_5        0.000142  Salience_VentralAttention_A               Visual_Central
# 3200     7       OFCANTR           PQR        0.000135                    Control_B                    Control_C
# 1860     8          SMAR       OFCLATR       -0.000133                Somatomotor_A    DefaultMode_VentralMedial
# 6784     9          LPCR          VER7        0.000133                Somatomotor_A       Background/NonCortical
# 1402    10        F3O_2R        HIPPOR       -0.000133    DefaultMode_VentralMedial            Limbic_A_TempPole
# 1064    11          F3TL           P1R       -0.000132                    Control_A            DorsalAttention_A
# 5378    12           O1R           NLR       -0.000131            Visual_Peripheral  Salience_VentralAttention_A
# 3385    13      OFCPOSTR           O1R        0.000131                 Limbic_B_OFC            Visual_Peripheral
# 7594    14          T2AR          VER9        0.000131            Limbic_A_TempPole       Background/NonCortical
# 1414    15        F3O_2R           O1R        0.000130    DefaultMode_VentralMedial            Visual_Peripheral
# 7278    16           T1L         tMDmL        0.000127                Somatomotor_B       Background/NonCortical
# 1422    17        F3O_2R           PAR       -0.000127    DefaultMode_VentralMedial                Somatomotor_A
# 5529    18           O2R          LPCR        0.000126            Visual_Peripheral                Somatomotor_A
# 7203    19       HESCHLR         CER3L        0.000125                Somatomotor_B                   Cerebellum
# 6691    20          LPCL         PALLR        0.000124                Somatomotor_A                Basal_Ganglia
# [INFO] [SALIENCY] Completo. Resultados en resultados33/fold_2/interpretability_xgb
# --- Procesando Fold 3 ---
# [INFO] [SHAP] fold=3 clf=xgb
# [INFO] [SHAP] Cargando datos de background CRUDOS desde: shap_background_raw_xgb.joblib
# [INFO] [SHAP] X_raw shape=(37, 259) (latentes + 3 metadatos)
# [INFO] [SHAP] Background DataFrame detectado pero columnas no coinciden; transformando…
# [INFO] [SHAP] Pack guardado: resultados33/fold_3/interpretability_shap/shap_pack_xgb.joblib
# [INFO] [SALIENCY] fold=3 clf=xgb  (pack cargado: shap_pack_xgb.joblib)
# [INFO] Usando ROI order de resultados33/roi_order_131.joblib.
# [INFO] Cargado fichero de anotaciones: /home/diego/Escritorio/limpio/roi_info_master.csv
# [INFO] [SALIENCY] 50 latentes ponderadas. Ejemplo:
#  latent_idx    weight  importance            feature
#         112  0.133941    0.241514 latent__latent_112
#          41  0.054311    0.097930  latent__latent_41
#          13 -0.050882   -0.091747  latent__latent_13
#         163  0.050194    0.090506 latent__latent_163
#         161  0.048229    0.086963 latent__latent_161
# [INFO] [SALIENCY] Sujetos AD=19  CN=18
# [INFO] [SALIENCY] Ranking de conexiones ANOTADO guardado: resultados33/fold_3/interpretability_xgb/ranking_conexiones_ANOTADO_top50.csv
# [INFO] Top 20 conexiones anotadas:
#       Rank src_AAL3_Name dst_AAL3_Name  Saliency_Score          src_Refined_Network     dst_Refined_Network
# 7167     1       HESCHLL        VER4_5        0.000276                Somatomotor_B          Visual_Central
# 4387     2        HIPPOR         CER6L        0.000203            Limbic_A_TempPole       Visual_Peripheral
# 5255     3         LINGR          VER7        0.000200               Visual_Central  Background/NonCortical
# 4662     4        AMYGDL        CER10L        0.000196            Limbic_A_TempPole              Cerebellum
# 4158     5          CIPR           O2L        0.000193     DefaultMode_DorsalMedial       Visual_Peripheral
# 1672     6           ORR           NLL        0.000191                Somatomotor_B  Background/NonCortical
# 3642     7       OFCLATR        VER4_5        0.000187    DefaultMode_VentralMedial          Visual_Central
# 7116     8         PALLR          VER6        0.000185                Basal_Ganglia       Visual_Peripheral
# 6895     9           NCR        CER10R        0.000184           Brainstem_Midbrain              Cerebellum
# 4584    10   PARA_HIPPOR          tVLR        0.000181            Limbic_A_TempPole  Background/NonCortical
# 6411    11          GSMR        CER10R        0.000179  Salience_VentralAttention_A              Cerebellum
# 4829    12           V1L        CER7BL        0.000178               Visual_Central              Cerebellum
# 6667    13           PQR          VER9        0.000175                    Control_C  Background/NonCortical
# 2864    14       OFCMEDL           V1R        0.000175                 Limbic_B_OFC          Visual_Central
# 6286    15           P2R          VER9        0.000174                    Control_B  Background/NonCortical
# 7008    16           NLR        VER4_5        0.000174  Salience_VentralAttention_A          Visual_Central
# 7826    17      CERCRU2R          VER3       -0.000169                   Cerebellum  Background/NonCortical
# 6417    18          GSMR          VER9        0.000169  Salience_VentralAttention_A  Background/NonCortical
# 1594    19           ORL          VER9        0.000169                Somatomotor_B  Background/NonCortical
# 4287    20        HIPPOL           T3R        0.000166             DefaultMode_Core       Limbic_A_TempPole
# [INFO] [SALIENCY] Completo. Resultados en resultados33/fold_3/interpretability_xgb
# --- Procesando Fold 4 ---
# [INFO] [SHAP] fold=4 clf=xgb
# [INFO] [SHAP] Cargando datos de background CRUDOS desde: shap_background_raw_xgb.joblib
# [INFO] [SHAP] X_raw shape=(37, 259) (latentes + 3 metadatos)
# [INFO] [SHAP] Background DataFrame detectado pero columnas no coinciden; transformando…
# [INFO] [SHAP] Pack guardado: resultados33/fold_4/interpretability_shap/shap_pack_xgb.joblib
# [INFO] [SALIENCY] fold=4 clf=xgb  (pack cargado: shap_pack_xgb.joblib)
# [INFO] Usando ROI order de resultados33/roi_order_131.joblib.
# [INFO] Cargado fichero de anotaciones: /home/diego/Escritorio/limpio/roi_info_master.csv
# [INFO] [SALIENCY] 50 latentes ponderadas. Ejemplo:
#  latent_idx    weight  importance            feature
#         233  0.106788    0.188453 latent__latent_233
#         144 -0.102639   -0.181130 latent__latent_144
#         245  0.100743    0.177784 latent__latent_245
#          22  0.075581    0.133380  latent__latent_22
#         213  0.057372    0.101246 latent__latent_213
# [INFO] [SALIENCY] Sujetos AD=19  CN=18
# [INFO] [SALIENCY] Ranking de conexiones ANOTADO guardado: resultados33/fold_4/interpretability_xgb/ranking_conexiones_ANOTADO_top50.csv
# [INFO] Top 20 conexiones anotadas:
#       Rank src_AAL3_Name dst_AAL3_Name  Saliency_Score          src_Refined_Network        dst_Refined_Network
# 5566     1           O2R          VER3       -0.000217            Visual_Peripheral     Background/NonCortical
# 6957     2           NLL          VER9        0.000191       Background/NonCortical     Background/NonCortical
# 5029     3            QR         LINGL        0.000172               Visual_Central             Visual_Central
# 5591     4           O3L         FUSIR        0.000165            Visual_Peripheral          Visual_Peripheral
# 6844     5           NCL          VER9        0.000154                 Limbic_B_OFC     Background/NonCortical
# 6412     6          GSMR          VER3       -0.000153  Salience_VentralAttention_A     Background/NonCortical
# 2087     7          COBR       OFCLATR        0.000153                 Limbic_B_OFC  DefaultMode_VentralMedial
# 7066     8         PALLL          VER9        0.000152                Basal_Ganglia     Background/NonCortical
# 4524     9   PARA_HIPPOR         FUSIL       -0.000151            Limbic_A_TempPole          Visual_Peripheral
# 6010    10           PAR          VER7       -0.000149                Somatomotor_A     Background/NonCortical
# 5195    11         LINGR           O1R        0.000148               Visual_Central          Visual_Peripheral
# 5007    12            QL        VER4_5       -0.000148               Visual_Central             Visual_Central
# 1434    13        F3O_2R          LPCR        0.000147    DefaultMode_VentralMedial              Somatomotor_A
# 6901    14           NCR          VER9        0.000142           Brainstem_Midbrain     Background/NonCortical
# 6223    15           P2L         tVPLL       -0.000135                    Control_A     Background/NonCortical
# 2130    16          COBR           NLL        0.000135                 Limbic_B_OFC     Background/NonCortical
# 6536    17           GAR         CER9R       -0.000131     DefaultMode_DorsalMedial                 Cerebellum
# 4542    18   PARA_HIPPOR           NLL       -0.000131            Limbic_A_TempPole     Background/NonCortical
# 2740    19           GRR       OFCANTR        0.000130                 Limbic_B_OFC                  Control_B
# 7367    20          T1AL          VER7        0.000126            Limbic_A_TempPole     Background/NonCortical
# [INFO] [SALIENCY] Completo. Resultados en resultados33/fold_4/interpretability_xgb
# --- Procesando Fold 5 ---
# [INFO] [SHAP] fold=5 clf=xgb
# [INFO] [SHAP] Cargando datos de background CRUDOS desde: shap_background_raw_xgb.joblib
# [INFO] [SHAP] X_raw shape=(36, 259) (latentes + 3 metadatos)
# [INFO] [SHAP] Background DataFrame detectado pero columnas no coinciden; transformando…
# [INFO] [SHAP] Pack guardado: resultados33/fold_5/interpretability_shap/shap_pack_xgb.joblib
# [INFO] [SALIENCY] fold=5 clf=xgb  (pack cargado: shap_pack_xgb.joblib)
# [INFO] Usando ROI order de resultados33/roi_order_131.joblib.
# [INFO] Cargado fichero de anotaciones: /home/diego/Escritorio/limpio/roi_info_master.csv
# [INFO] [SALIENCY] 50 latentes ponderadas. Ejemplo:
#  latent_idx   weight  importance            feature
#          69 0.205878    0.081490  latent__latent_69
#         230 0.186928    0.073989 latent__latent_230
#         110 0.102489    0.040567 latent__latent_110
#          36 0.056573    0.022393  latent__latent_36
#          10 0.031222    0.012358  latent__latent_10
# [INFO] [SALIENCY] Sujetos AD=19  CN=17
# [INFO] [SALIENCY] Ranking de conexiones ANOTADO guardado: resultados33/fold_5/interpretability_xgb/ranking_conexiones_ANOTADO_top50.csv
# [INFO] Top 20 conexiones anotadas:
#       Rank src_AAL3_Name dst_AAL3_Name  Saliency_Score          src_Refined_Network          dst_Refined_Network
# 7169     1       HESCHLL          VER7        0.000258                Somatomotor_B       Background/NonCortical
# 7959     2       CER4_5R         CER8R        0.000252               Visual_Central                   Cerebellum
# 4037     3         CINMR         tVPLR        0.000244  Salience_VentralAttention_A       Background/NonCortical
# 3986     4         CINMR           GAR       -0.000243  Salience_VentralAttention_A     DefaultMode_DorsalMedial
# 5356     5           O1R           O2R       -0.000240            Visual_Peripheral            Visual_Peripheral
# 3956     6         CINMR          CIPR        0.000231  Salience_VentralAttention_A     DefaultMode_DorsalMedial
# 2747     7           GRR         CINML        0.000231                 Limbic_B_OFC  Salience_VentralAttention_A
# 6155     8           P1R         tVPLL       -0.000227            DorsalAttention_A       Background/NonCortical
# 2957     9       OFCMEDR           INR        0.000223                 Limbic_B_OFC  Salience_VentralAttention_A
# 3889    10         CINML          GSMR       -0.000217  Salience_VentralAttention_A  Salience_VentralAttention_A
# 6750    11          LPCR         PALLR        0.000215                Somatomotor_A                Basal_Ganglia
# 7012    12           NLR          VER9        0.000215  Salience_VentralAttention_A       Background/NonCortical
# 2097    13          COBR   PARA_HIPPOR        0.000215                 Limbic_B_OFC            Limbic_A_TempPole
# 2089    14          COBR           INR        0.000214                 Limbic_B_OFC  Salience_VentralAttention_A
# 3972    15         CINMR           O2R       -0.000212  Salience_VentralAttention_A            Visual_Peripheral
# 2312    16           FMR           INR        0.000212     DefaultMode_DorsalMedial  Salience_VentralAttention_A
# 4035    17         CINMR          tVLR        0.000212  Salience_VentralAttention_A       Background/NonCortical
# 6261    18           P2R           T3L        0.000209                    Control_B            Limbic_A_TempPole
# 2173    19          COBR         tVPLL       -0.000209                 Limbic_B_OFC       Background/NonCortical
# 3921    20         CINML       CER4_5R        0.000207  Salience_VentralAttention_A               Visual_Central
# [INFO] [SALIENCY] Completo. Resultados en resultados33/fold_5/interpretability_xgb
# ✅ ¡Análisis de interpretabilidad para todos los folds completado!

# %%
# CELDA 1 ─── imports y paths
import json, glob, numpy as np, scipy.stats as st
from skimage.metrics import adapted_rand_error as dice   # 1–ARE ≈ Dice
RUN_DIR = "./resultados33"
SAL_MAPS = sorted(glob.glob(f"{RUN_DIR}/fold_*/interpretability_xgb/saliency_map_diff_top50.npy"))
assert len(SAL_MAPS) == 5, f"Faltan mapas: {SAL_MAPS}"

# %%
# CELDA 2 ─── grand average + métricas
diff_maps = [np.load(p) for p in SAL_MAPS]                 # list len=5, shape (C,R,R)
diff_avg  = np.mean(diff_maps, axis=0).astype(np.float32)  # (C,R,R)
np.save(f"{RUN_DIR}/grand_average_saliency.npy", diff_avg)

# vector upper-triangular por fold (promedio sobre canales)
vecs = [m.mean(axis=0)[np.triu_indices(m.shape[-1],1)] for m in diff_maps]
# Pearson ρ y Dice inter-fold
n     = len(vecs)
rhos  = [st.pearsonr(vecs[i], vecs[j])[0]        for i in range(n) for j in range(i+1,n)]
dices = [1-dice(vecs[i]>0, vecs[j]>0)[0]         for i in range(n) for j in range(i+1,n)]

stats = {
    "rho_mean":        float(np.mean(rhos)),   "rho_std":   float(np.std(rhos)),
    "dice_mean":       float(np.mean(dices)),  "dice_std":  float(np.std(dices)),
    "sign_agreement":  float(np.mean([(v1>0)==(v2>0) for i,v1 in enumerate(vecs) for v2 in vecs[i+1:]]))
}
json.dump(stats, open(f"{RUN_DIR}/saliency_stats.json","w"), indent=2)
stats
# Out:
# {'rho_mean': 0.01309380866587162,
#  'rho_std': 0.019735191017389297,
#  'dice_mean': 0.6778316811769827,
#  'dice_std': 0.017419429334272082,
#  'sign_agreement': 0.5057193188490898}

# %%
# CELDA 3 ─── heat-map del patrón medio (opcional figura para el paper)
import seaborn as sns, matplotlib.pyplot as plt
roi_names = np.load("/home/diego/Escritorio/limpio/roi_order_131.npy")
plt.figure(figsize=(10,8))
sns.heatmap(diff_avg.mean(axis=0), cmap="coolwarm", center=0,
            xticklabels=roi_names, yticklabels=roi_names,
            cbar_kws=dict(label="Saliencia AD > CN"))
plt.title("Grand-average saliency (XGB, top-50 latentes, n=5 folds)")
plt.tight_layout(); plt.savefig(f"{RUN_DIR}/grand_average_heatmap.png", dpi=300)
plt.show()

# %%
import glob, pandas as pd, numpy as np, scipy.stats as st
RUN_DIR = "./resultados33"                       # <- ajusta si cambias de carpeta
csv_paths = sorted(
    glob.glob(f"{RUN_DIR}/fold_*/interpretability_xgb/"
              "ranking_conexiones_ANOTADO_top50.csv")
)

dfs = []
for fold, path in enumerate(csv_paths, 1):
    df = (pd.read_csv(path)
            .assign(fold=fold)
            .rename(columns={'Saliency_Score': 'score'}))
    
    # ⚠️ Nos aseguramos de que el identificador del edge sea INDEPENDIENTE del orden
    df['edge_id'] = (df[['src_AAL3_Name', 'dst_AAL3_Name']]
                     .apply(lambda r: ' — '.join(sorted(r)), axis=1))
    dfs.append(df[['edge_id', 'score', 'fold']])

all_edges = pd.concat(dfs, ignore_index=True)

# %%
def ci95(series):
    """IC95 % bilateral para n<=30 usando t de Student."""
    n = series.size
    m = series.mean()
    s = series.std(ddof=1)
    t_crit = st.t.ppf(0.975, df=n-1)
    half_width = t_crit * s / np.sqrt(n)
    return pd.Series({'mean': m, 'ci_low': m-half_width, 'ci_high': m+half_width})

edge_stats = (all_edges
              .groupby('edge_id')['score']
              .apply(ci95)        # devuelve Serie con índice 'mean', 'ci_low', …
              .unstack()          # pasa ese índice a columnas
              .reset_index())     # deja 'edge_id' como columna normal


# ordenamos por |media| y nos quedamos con los 10 primeros
top10 = (edge_stats
         .assign(abs_mean=lambda d: d['mean'].abs())
         .sort_values('abs_mean', ascending=False)
         .head(10)
         .drop(columns='abs_mean'))

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))

y = np.arange(len(top10))[::-1]            # barras horizontales (de arriba abajo)
plt.barh(y,  top10['mean'], xerr=[top10['mean']-top10['ci_low'],
                                  top10['ci_high']-top10['mean']],
         alpha=0.8, capsize=4)

plt.yticks(y, top10['edge_id'])
plt.xlabel('Saliencia diferencial (AD > CN)')
plt.title('Top-10 conexiones | media ± IC 95 % (5 folds)')
plt.tight_layout()
plt.savefig(f"{RUN_DIR}/fig_top10_edges_ic95.png", dpi=300)
plt.show()

# %%
top10.to_csv(f"{RUN_DIR}/top10_edges_ic95.csv", index=False)

# %%
import numpy as np
sal = np.load("/home/diego/Escritorio/limpio/resultados33/grand_average_saliency.npy")        # shape (C, R, R)
print("Shape de la saliencia:", sal.shape)
w_r = sal.mean(0).sum(axis=0) + sal.mean(0).sum(axis=1)  # col + row
w_r = np.abs(w_r); w_r /= w_r.sum()                # normaliza
np.save("roi_weights.npy", w_r)
print("Pesos de las ROIs guardados en 'roi_weights.npy'.")
# Out:
# Shape de la saliencia: (2, 131, 131)
# Pesos de las ROIs guardados en 'roi_weights.npy'.

# %%
from nilearn import plotting
atlas_nii = "AAL3_131_in_MNI.nii.gz"               # tu atlas reordenado
plotting.plot_surf_stat_map(
    surf_mesh='fsaverage5_inflated_left.gii',
    stat_map=w_r[left_hemi_indices],
    hemi='left', colorbar=True, cmap='hot_r')
# Repítelo para el hemisferio derecho y guarda con plt.savefig(...)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 5
#       1 from nilearn import plotting
#       2 atlas_nii = "AAL3_131_in_MNI.nii.gz"               # tu atlas reordenado
#       3 plotting.plot_surf_stat_map(
#       4     surf_mesh='fsaverage5_inflated_left.gii',
# ----> 5     stat_map=w_r[left_hemi_indices],
#       6     hemi='left', colorbar=True, cmap='hot_r')
#       7 # Repítelo para el hemisferio derecho y guarda con plt.savefig(...)
#
# NameError: name 'left_hemi_indices' is not defined
