# %%
# !python channel_ablation_study_rfe.py \
    --global_tensor_path /home/diego/Escritorio/limpio/AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned/GLOBAL_TENSOR_from_AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned.npz \
    --metadata_path /home/diego/Escritorio/limpio/SubjectsData_AAL3_procesado.csv \
    --output_dir ./resultados_rfe_con_metadata \
    --run-rfe \
    --classifier_types logreg \
    --cyclical_beta_n_cycles 3 \
    --cyclical_beta_ratio_increase 0.3 \
    --lr_scheduler_type cosine_warm \
    --lr_scheduler_T0 50 \
    --lr_scheduler_eta_min 1e-7 \
    --n_jobs_gridsearch 1 \
    --metadata_features Age Sex \
    --use_smote \
    --classifier_use_class_weight
# Out:
# ¿GPU visible?: True
# ¿GPU visible?: True
# ¿GPU visible?: True
# torch.cuda.is_available -> True
# torch.version.cuda      -> 11.8
# cupy GPU visible        -> True
# fatal: no es un repositorio git (ni ninguno de los directorios superiores): .git
# [INFO] Cargando tensor global desde: /home/diego/Escritorio/limpio/AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned/GLOBAL_TENSOR_from_AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned.npz
# [INFO] Tensor global cargado. Forma: (431, 7, 131, 131)
# [INFO] Cargando metadatos desde: /home/diego/Escritorio/limpio/SubjectsData_AAL3_procesado.csv
# [INFO] Metadatos cargados. Forma: (434, 32)
# [INFO] Canales encontrados en el tensor: ['Pearson_OMST_GCE_Signed_Weighted', 'Pearson_Full_FisherZ_Signed', 'MI_KNN_Symmetric', 'dFC_AbsDiffMean', 'dFC_StdDev', 'DistanceCorr', 'Granger_F_lag1']
# [INFO] --- INICIANDO ESTUDIO DE ELIMINACIÓN RECURSIVA DE CARACTERÍSTICAS (RFE) ---
# [INFO] --- Iniciando iteración RFE con 7 canales ---
# [INFO] Canales actuales: ['Pearson_OMST_GCE_Signed_Weighted', 'Pearson_Full_FisherZ_Signed', 'MI_KNN_Symmetric', 'dFC_AbsDiffMean', 'dFC_StdDev', 'DistanceCorr', 'Granger_F_lag1']
# [INFO] --- Iniciando Estudio de Ablación para 7 canales ---
# [INFO] Usando canales seleccionados (índices): [0, 1, 2, 3, 4, 5, 6]
# [INFO] Nombres de canales seleccionados: ['Pearson_OMST_GCE_Signed_Weighted', 'Pearson_Full_FisherZ_Signed', 'MI_KNN_Symmetric', 'dFC_AbsDiffMean', 'dFC_StdDev', 'DistanceCorr', 'Granger_F_lag1']
# [INFO] Estratificando folds del CLASIFICADOR por: ['ResearchGroup_Mapped', 'Sex']
# [INFO] Sujetos CN/AD para clasificación: 184. CN: 89, AD: 95
# [INFO] Usando CV externa: StratifiedKFold con 3 iteraciones totales.
# [INFO] --- Iniciando Fold 1/3 ---
# [INFO] Fold 1/3 Test Set (Clasificador) (N=62):
#     ResearchGroup_Mapped:
#       AD: 32 (51.6%)
#       CN: 30 (48.4%)
#     Sex:
#       F: 32 (51.6%)
#       M: 30 (48.4%)
# [INFO] Fold 1/3 Pool Entrenamiento VAE (N=369):
#     ResearchGroup_Mapped:
#       AD: 63 (17.1%)
#       CN: 59 (16.0%)
#       MCI: 247 (66.9%)
#     Sex:
#       F: 174 (47.2%)
#       M: 195 (52.8%)
#     Age_Group:
#       0: 98 (26.6%)
#       1: 95 (25.7%)
#       2: 83 (22.5%)
#       3: 93 (25.2%)
# [INFO]   Fold 1/3 VAE val split será estratificado por ['ResearchGroup_Mapped', 'Sex', 'Age_Group'].
# [INFO] Fold 1/3 Actual Train Set (VAE) (N=295):
#     ResearchGroup_Mapped:
#       AD: 50 (16.9%)
#       CN: 48 (16.3%)
#       MCI: 197 (66.8%)
#     Sex:
#       F: 138 (46.8%)
#       M: 157 (53.2%)
#     Age_Group:
#       0: 79 (26.8%)
#       1: 76 (25.8%)
#       2: 66 (22.4%)
#       3: 74 (25.1%)
# [INFO] Fold 1/3 Internal Val Set (VAE) (N=74):
#     ResearchGroup_Mapped:
#       AD: 13 (17.6%)
#       CN: 11 (14.9%)
#       MCI: 50 (67.6%)
#     Sex:
#       F: 36 (48.6%)
#       M: 38 (51.4%)
#     Age_Group:
#       0: 19 (25.7%)
#       1: 19 (25.7%)
#       2: 17 (23.0%)
#       3: 19 (25.7%)
# [INFO]   Fold 1/3 Sujetos VAE actual train: 295, VAE internal val: 74
# [INFO] Aplicando normalización inter-canal (modo: zscore_offdiag) sobre 7 canales seleccionados.
# [INFO] Parámetros de normalización se calcularán usando 295 sujetos de entrenamiento.
# [INFO] Canal 'Pearson_OMST_GCE_Signed_Weighted': Off-diag zscore_offdiag (train_params: mean=0.310, std=1.091)
# [INFO] Canal 'Pearson_Full_FisherZ_Signed': Off-diag zscore_offdiag (train_params: mean=-0.048, std=0.777)
# [INFO] Canal 'MI_KNN_Symmetric': Off-diag zscore_offdiag (train_params: mean=0.056, std=0.815)
# [INFO] Canal 'dFC_AbsDiffMean': Off-diag zscore_offdiag (train_params: mean=-0.037, std=0.767)
# [INFO] Canal 'dFC_StdDev': Off-diag zscore_offdiag (train_params: mean=0.035, std=0.715)
# [INFO] Canal 'DistanceCorr': Off-diag zscore_offdiag (train_params: mean=-0.402, std=1.628)
# [INFO] Canal 'Granger_F_lag1': Off-diag zscore_offdiag (train_params: mean=0.410, std=1.102)
# [INFO]   Fold 1/3 Usando dispositivo: cuda
# [INFO]   Fold 1/3 Usando scheduler: CosineAnnealingWarmRestarts (T_0=50)
# [INFO]   Fold 1/3 Entrenando VAE (Decoder: convtranspose, Encoder Layers: 4)...
# [INFO]   Fold 1/3 VAE E50/550, TrL: 116411.53 (R: 115748.04, KLD: 297.90), Beta: 2.227, LR: 1.04e-07, ValL: 117069.23 (R: 116496.81, KLD: 257.00)
# [INFO]   Fold 1/3 VAE E100/550, TrL: 103984.96 (R: 103454.78, KLD: 212.07), Beta: 2.500, LR: 1.04e-07, ValL: 104370.73 (R: 103942.60, KLD: 171.25)
# [INFO]   Fold 1/3 VAE E150/550, TrL: 98699.57 (R: 98123.33, KLD: 230.49), Beta: 2.500, LR: 1.04e-07, ValL: 99199.91 (R: 98751.45, KLD: 179.38)
# [INFO]   Fold 1/3 VAE E200/550, TrL: 94947.67 (R: 94753.32, KLD: 272.91), Beta: 0.712, LR: 1.04e-07, ValL: 96102.13 (R: 95954.81, KLD: 206.88)
# [INFO]   Fold 1/3 VAE E250/550, TrL: 93271.27 (R: 92493.67, KLD: 311.04), Beta: 2.500, LR: 1.04e-07, ValL: 94721.02 (R: 94196.45, KLD: 209.83)
# [INFO]   Fold 1/3 VAE E300/550, TrL: 91549.95 (R: 90832.29, KLD: 287.06), Beta: 2.500, LR: 1.04e-07, ValL: 93386.10 (R: 92925.43, KLD: 184.27)
# [INFO]   Fold 1/3 VAE E350/550, TrL: 90145.40 (R: 89404.38, KLD: 296.41), Beta: 2.500, LR: 1.04e-07, ValL: 92488.04 (R: 92024.78, KLD: 185.30)
# [INFO]   Fold 1/3 Early stopping VAE en epoch 398. Mejor val_loss: 91361.2705
# [INFO]   Fold 1/3 VAE final model loaded (best val_loss: 91361.2705).
# [INFO]   Fold 1/3 Modelo VAE guardado en: resultados_rfe_con_metadata/rfe_step_7_channels/fold_1/vae_model_fold_1.pt
# [INFO] Fold 1/3 Pool Train/Dev (Clasificador) (N=122):
#     ResearchGroup_Mapped:
#       AD: 63 (51.6%)
#       CN: 59 (48.4%)
#     Sex:
#       F: 60 (49.2%)
#       M: 62 (50.8%)
# [INFO]   Añadiendo metadatos al clasificador: ['Age', 'Sex']
# [INFO]   Forma final del set de entrenamiento del clasificador: (122, 514)
# [INFO]     --- Entrenando Clasificador: logreg ---
# [INFO] [SMOTE] ➜ Usando implementación de imblearn (CPU) para el clasificador 'logreg'.
# [INFO]       Mejores HPs para logreg: {'model__C': 0.0027742416615562818}
# [INFO]       Modelo final (pipeline) para logreg listo.
# [INFO]       Resultados Fold 1 (logreg): AUC=0.7969, Bal.Acc=0.7083
# [INFO]       Pipeline completo de logreg del fold 1 guardado.
# [INFO]   Fold 1/3 completado en 227.93 segundos.
# [INFO] --- Iniciando Fold 2/3 ---
# [INFO] Fold 2/3 Test Set (Clasificador) (N=61):
#     ResearchGroup_Mapped:
#       AD: 31 (50.8%)
#       CN: 30 (49.2%)
#     Sex:
#       F: 30 (49.2%)
#       M: 31 (50.8%)
# [INFO] Fold 2/3 Pool Entrenamiento VAE (N=370):
#     ResearchGroup_Mapped:
#       AD: 64 (17.3%)
#       CN: 59 (15.9%)
#       MCI: 247 (66.8%)
#     Sex:
#       F: 176 (47.6%)
#       M: 194 (52.4%)
#     Age_Group:
#       0: 91 (24.6%)
#       1: 96 (25.9%)
#       2: 91 (24.6%)
#       3: 92 (24.9%)
# [INFO]   Fold 2/3 VAE val split será estratificado por ['ResearchGroup_Mapped', 'Sex', 'Age_Group'].
# [INFO] Fold 2/3 Actual Train Set (VAE) (N=296):
#     ResearchGroup_Mapped:
#       AD: 51 (17.2%)
#       CN: 47 (15.9%)
#       MCI: 198 (66.9%)
#     Sex:
#       F: 140 (47.3%)
#       M: 156 (52.7%)
#     Age_Group:
#       0: 73 (24.7%)
#       1: 78 (26.4%)
#       2: 72 (24.3%)
#       3: 73 (24.7%)
# [INFO] Fold 2/3 Internal Val Set (VAE) (N=74):
#     ResearchGroup_Mapped:
#       AD: 13 (17.6%)
#       CN: 12 (16.2%)
#       MCI: 49 (66.2%)
#     Sex:
#       F: 36 (48.6%)
#       M: 38 (51.4%)
#     Age_Group:
#       0: 18 (24.3%)
#       1: 18 (24.3%)
#       2: 19 (25.7%)
#       3: 19 (25.7%)
# [INFO]   Fold 2/3 Sujetos VAE actual train: 296, VAE internal val: 74
# [INFO] Aplicando normalización inter-canal (modo: zscore_offdiag) sobre 7 canales seleccionados.
# [INFO] Parámetros de normalización se calcularán usando 296 sujetos de entrenamiento.
# [INFO] Canal 'Pearson_OMST_GCE_Signed_Weighted': Off-diag zscore_offdiag (train_params: mean=0.309, std=1.090)
# [INFO] Canal 'Pearson_Full_FisherZ_Signed': Off-diag zscore_offdiag (train_params: mean=-0.046, std=0.774)
# [INFO] Canal 'MI_KNN_Symmetric': Off-diag zscore_offdiag (train_params: mean=0.060, std=0.812)
# [INFO] Canal 'dFC_AbsDiffMean': Off-diag zscore_offdiag (train_params: mean=-0.035, std=0.766)
# [INFO] Canal 'dFC_StdDev': Off-diag zscore_offdiag (train_params: mean=0.034, std=0.714)
# [INFO] Canal 'DistanceCorr': Off-diag zscore_offdiag (train_params: mean=-0.401, std=1.689)
# [INFO] Canal 'Granger_F_lag1': Off-diag zscore_offdiag (train_params: mean=0.409, std=1.099)
# [INFO]   Fold 2/3 Usando dispositivo: cuda
# [INFO]   Fold 2/3 Usando scheduler: CosineAnnealingWarmRestarts (T_0=50)
# [INFO]   Fold 2/3 Entrenando VAE (Decoder: convtranspose, Encoder Layers: 4)...
# [INFO]   Fold 2/3 VAE E50/550, TrL: 115651.40 (R: 114949.07, KLD: 315.33), Beta: 2.227, LR: 1.04e-07, ValL: 114138.01 (R: 113463.79, KLD: 302.71)
# [INFO]   Fold 2/3 VAE E100/550, TrL: 103856.51 (R: 103295.73, KLD: 224.31), Beta: 2.500, LR: 1.04e-07, ValL: 101577.17 (R: 101122.65, KLD: 181.81)
# [INFO]   Fold 2/3 VAE E150/550, TrL: 98600.58 (R: 97996.24, KLD: 241.74), Beta: 2.500, LR: 1.04e-07, ValL: 96392.32 (R: 95921.67, KLD: 188.26)
# [INFO]   Fold 2/3 VAE E200/550, TrL: 94646.59 (R: 94443.82, KLD: 284.74), Beta: 0.712, LR: 1.04e-07, ValL: 93210.42 (R: 93052.88, KLD: 221.23)
# [INFO]   Fold 2/3 VAE E250/550, TrL: 92957.51 (R: 92156.19, KLD: 320.53), Beta: 2.500, LR: 1.04e-07, ValL: 91802.18 (R: 91228.07, KLD: 229.64)
# [INFO]   Fold 2/3 VAE E300/550, TrL: 91396.35 (R: 90652.39, KLD: 297.58), Beta: 2.500, LR: 1.04e-07, ValL: 90665.66 (R: 90166.54, KLD: 199.65)
# [INFO]   Fold 2/3 VAE E350/550, TrL: 89818.05 (R: 89060.88, KLD: 302.87), Beta: 2.500, LR: 1.04e-07, ValL: 89932.96 (R: 89444.24, KLD: 195.49)
# [INFO]   Fold 2/3 VAE E400/550, TrL: 88435.45 (R: 87868.97, KLD: 385.44), Beta: 1.470, LR: 1.04e-07, ValL: 89164.37 (R: 88795.65, KLD: 250.88)
# [INFO]   Fold 2/3 Early stopping VAE en epoch 401. Mejor val_loss: 88865.6406
# [INFO]   Fold 2/3 VAE final model loaded (best val_loss: 88865.6406).
# [INFO]   Fold 2/3 Modelo VAE guardado en: resultados_rfe_con_metadata/rfe_step_7_channels/fold_2/vae_model_fold_2.pt
# [INFO] Fold 2/3 Pool Train/Dev (Clasificador) (N=123):
#     ResearchGroup_Mapped:
#       AD: 64 (52.0%)
#       CN: 59 (48.0%)
#     Sex:
#       F: 62 (50.4%)
#       M: 61 (49.6%)
# [INFO]   Añadiendo metadatos al clasificador: ['Age', 'Sex']
# [INFO]   Forma final del set de entrenamiento del clasificador: (123, 514)
# [INFO]     --- Entrenando Clasificador: logreg ---
# [INFO] [SMOTE] ➜ Usando implementación de imblearn (CPU) para el clasificador 'logreg'.
# [INFO]       Mejores HPs para logreg: {'model__C': 0.0036004820165493373}
# [INFO]       Modelo final (pipeline) para logreg listo.
# [INFO]       Resultados Fold 2 (logreg): AUC=0.7452, Bal.Acc=0.6398
# [INFO]       Pipeline completo de logreg del fold 2 guardado.
# [INFO]   Fold 2/3 completado en 235.52 segundos.
# [INFO] --- Iniciando Fold 3/3 ---
# [INFO] Fold 3/3 Test Set (Clasificador) (N=61):
#     ResearchGroup_Mapped:
#       AD: 32 (52.5%)
#       CN: 29 (47.5%)
#     Sex:
#       F: 30 (49.2%)
#       M: 31 (50.8%)
# [INFO] Fold 3/3 Pool Entrenamiento VAE (N=370):
#     ResearchGroup_Mapped:
#       AD: 63 (17.0%)
#       CN: 60 (16.2%)
#       MCI: 247 (66.8%)
#     Sex:
#       F: 176 (47.6%)
#       M: 194 (52.4%)
#     Age_Group:
#       0: 94 (25.4%)
#       1: 95 (25.7%)
#       2: 94 (25.4%)
#       3: 87 (23.5%)
# [INFO]   Fold 3/3 VAE val split será estratificado por ['ResearchGroup_Mapped', 'Sex', 'Age_Group'].
# [INFO] Fold 3/3 Actual Train Set (VAE) (N=296):
#     ResearchGroup_Mapped:
#       AD: 50 (16.9%)
#       CN: 49 (16.6%)
#       MCI: 197 (66.6%)
#     Sex:
#       F: 142 (48.0%)
#       M: 154 (52.0%)
#     Age_Group:
#       0: 76 (25.7%)
#       1: 76 (25.7%)
#       2: 75 (25.3%)
#       3: 69 (23.3%)
# [INFO] Fold 3/3 Internal Val Set (VAE) (N=74):
#     ResearchGroup_Mapped:
#       AD: 13 (17.6%)
#       CN: 11 (14.9%)
#       MCI: 50 (67.6%)
#     Sex:
#       F: 34 (45.9%)
#       M: 40 (54.1%)
#     Age_Group:
#       0: 18 (24.3%)
#       1: 19 (25.7%)
#       2: 19 (25.7%)
#       3: 18 (24.3%)
# [INFO]   Fold 3/3 Sujetos VAE actual train: 296, VAE internal val: 74
# [INFO] Aplicando normalización inter-canal (modo: zscore_offdiag) sobre 7 canales seleccionados.
# [INFO] Parámetros de normalización se calcularán usando 296 sujetos de entrenamiento.
# [INFO] Canal 'Pearson_OMST_GCE_Signed_Weighted': Off-diag zscore_offdiag (train_params: mean=0.309, std=1.092)
# [INFO] Canal 'Pearson_Full_FisherZ_Signed': Off-diag zscore_offdiag (train_params: mean=-0.051, std=0.780)
# [INFO] Canal 'MI_KNN_Symmetric': Off-diag zscore_offdiag (train_params: mean=0.053, std=0.813)
# [INFO] Canal 'dFC_AbsDiffMean': Off-diag zscore_offdiag (train_params: mean=-0.036, std=0.767)
# [INFO] Canal 'dFC_StdDev': Off-diag zscore_offdiag (train_params: mean=0.036, std=0.714)
# [INFO] Canal 'DistanceCorr': Off-diag zscore_offdiag (train_params: mean=-0.425, std=1.798)
# [INFO] Canal 'Granger_F_lag1': Off-diag zscore_offdiag (train_params: mean=0.409, std=1.101)
# [INFO]   Fold 3/3 Usando dispositivo: cuda
# [INFO]   Fold 3/3 Usando scheduler: CosineAnnealingWarmRestarts (T_0=50)
# [INFO]   Fold 3/3 Entrenando VAE (Decoder: convtranspose, Encoder Layers: 4)...
# [INFO]   Fold 3/3 VAE E50/550, TrL: 116306.48 (R: 115630.53, KLD: 303.49), Beta: 2.227, LR: 1.04e-07, ValL: 107533.42 (R: 106860.10, KLD: 302.31)
# [INFO]   Fold 3/3 VAE E100/550, TrL: 104731.26 (R: 104214.39, KLD: 206.75), Beta: 2.500, LR: 1.04e-07, ValL: 95829.30 (R: 95394.04, KLD: 174.10)
# [INFO]   Fold 3/3 VAE E150/550, TrL: 99327.80 (R: 98761.48, KLD: 226.53), Beta: 2.500, LR: 1.04e-07, ValL: 90565.06 (R: 90110.94, KLD: 181.65)
# [INFO]   Fold 3/3 VAE E200/550, TrL: 95533.79 (R: 95341.30, KLD: 270.30), Beta: 0.712, LR: 1.04e-07, ValL: 87244.83 (R: 87098.53, KLD: 205.44)
# [INFO]   Fold 3/3 VAE E250/550, TrL: 93594.86 (R: 92830.08, KLD: 305.91), Beta: 2.500, LR: 1.04e-07, ValL: 85689.75 (R: 85153.08, KLD: 214.67)
# [INFO]   Fold 3/3 VAE E300/550, TrL: 91835.19 (R: 91119.30, KLD: 286.36), Beta: 2.500, LR: 1.04e-07, ValL: 84459.54 (R: 83993.29, KLD: 186.50)
# [INFO]   Fold 3/3 VAE E350/550, TrL: 90665.18 (R: 89926.96, KLD: 295.29), Beta: 2.500, LR: 1.04e-07, ValL: 83496.57 (R: 83037.28, KLD: 183.72)
# [INFO]   Fold 3/3 VAE E400/550, TrL: 89011.08 (R: 88457.47, KLD: 376.68), Beta: 1.470, LR: 1.04e-07, ValL: 82649.25 (R: 82295.21, KLD: 240.89)
# [INFO]   Fold 3/3 Early stopping VAE en epoch 404. Mejor val_loss: 82520.3725
# [INFO]   Fold 3/3 VAE final model loaded (best val_loss: 82520.3725).
# [INFO]   Fold 3/3 Modelo VAE guardado en: resultados_rfe_con_metadata/rfe_step_7_channels/fold_3/vae_model_fold_3.pt
# [INFO] Fold 3/3 Pool Train/Dev (Clasificador) (N=123):
#     ResearchGroup_Mapped:
#       AD: 63 (51.2%)
#       CN: 60 (48.8%)
#     Sex:
#       F: 62 (50.4%)
#       M: 61 (49.6%)
# [INFO]   Añadiendo metadatos al clasificador: ['Age', 'Sex']
# [INFO]   Forma final del set de entrenamiento del clasificador: (123, 514)
# [INFO]     --- Entrenando Clasificador: logreg ---
# [INFO] [SMOTE] ➜ Usando implementación de imblearn (CPU) para el clasificador 'logreg'.
# [INFO]       Mejores HPs para logreg: {'model__C': 0.008967370332313384}
# [INFO]       Modelo final (pipeline) para logreg listo.
# [INFO]       Resultados Fold 3 (logreg): AUC=0.7144, Bal.Acc=0.6180
# [INFO]       Pipeline completo de logreg del fold 3 guardado.
# [INFO]   Fold 3/3 completado en 233.38 segundos.
# [INFO]
# --- Resumen de Rendimiento para Clasificador: logreg (Promedio sobre Folds Externos) ---
# [INFO] Auc                 : 0.7522 +/- 0.0417
# [INFO] Pr_auc              : 0.7570 +/- 0.0569
# [INFO] Accuracy            : 0.6573 +/- 0.0461
# [INFO] Balanced_accuracy   : 0.6554 +/- 0.0471
# [INFO] Sensitivity         : 0.6939 +/- 0.0719
# [INFO] Specificity         : 0.6169 +/- 0.0863
# [INFO] F1_score            : 0.6758 +/- 0.0476
# [INFO] Resultados detallados de todos los clasificadores guardados en: resultados_rfe_con_metadata/rfe_step_7_channels/all_folds_metrics_MULTI_logreg_vaeconvtranspose4l_ld512_beta2.5_normzscore_offdiag_ch7sel_intFCquarter_drop0.2_ln0_outer3x1_scorebalanced_accuracy.csv
# [INFO] Sumario estadístico de métricas (por clasificador) guardado en: resultados_rfe_con_metadata/rfe_step_7_channels/summary_metrics_MULTI_logreg_vaeconvtranspose4l_ld512_beta2.5_normzscore_offdiag_ch7sel_intFCquarter_drop0.2_ln0_outer3x1_scorebalanced_accuracy.txt
# [INFO] Rendimiento de referencia (7 canales): 0.6554
# Ablación de 7 canales:   0%|                              | 0/7 [00:00<?, ?it/s][INFO] Usando canales seleccionados (índices): [1, 2, 3, 4, 5, 6]
# [INFO] Nombres de canales seleccionados: ['Pearson_Full_FisherZ_Signed', 'MI_KNN_Symmetric', 'dFC_AbsDiffMean', 'dFC_StdDev', 'DistanceCorr', 'Granger_F_lag1']
# [INFO] Estratificando folds del CLASIFICADOR por: ['ResearchGroup_Mapped', 'Sex']
# [INFO] Sujetos CN/AD para clasificación: 184. CN: 89, AD: 95
# [INFO] Usando CV externa: StratifiedKFold con 3 iteraciones totales.
# [INFO] --- Iniciando Fold 1/3 ---
# [INFO] Fold 1/3 Test Set (Clasificador) (N=62):
#     ResearchGroup_Mapped:
#       AD: 32 (51.6%)
#       CN: 30 (48.4%)
#     Sex:
#       F: 32 (51.6%)
#       M: 30 (48.4%)
# [INFO] Fold 1/3 Pool Entrenamiento VAE (N=369):
#     ResearchGroup_Mapped:
#       AD: 63 (17.1%)
#       CN: 59 (16.0%)
#       MCI: 247 (66.9%)
#     Sex:
#       F: 174 (47.2%)
#       M: 195 (52.8%)
#     Age_Group:
#       0: 98 (26.6%)
#       1: 95 (25.7%)
#       2: 83 (22.5%)
#       3: 93 (25.2%)
# [INFO]   Fold 1/3 VAE val split será estratificado por ['ResearchGroup_Mapped', 'Sex', 'Age_Group'].
# [INFO] Fold 1/3 Actual Train Set (VAE) (N=295):
#     ResearchGroup_Mapped:
#       AD: 50 (16.9%)
#       CN: 48 (16.3%)
#       MCI: 197 (66.8%)
#     Sex:
#       F: 138 (46.8%)
#       M: 157 (53.2%)
#     Age_Group:
#       0: 79 (26.8%)
#       1: 76 (25.8%)
#       2: 66 (22.4%)
#       3: 74 (25.1%)
# [INFO] Fold 1/3 Internal Val Set (VAE) (N=74):
#     ResearchGroup_Mapped:
#       AD: 13 (17.6%)
#       CN: 11 (14.9%)
#       MCI: 50 (67.6%)
#     Sex:
#       F: 36 (48.6%)
#       M: 38 (51.4%)
#     Age_Group:
#       0: 19 (25.7%)
#       1: 19 (25.7%)
#       2: 17 (23.0%)
#       3: 19 (25.7%)
# [INFO]   Fold 1/3 Sujetos VAE actual train: 295, VAE internal val: 74
# [INFO] Aplicando normalización inter-canal (modo: zscore_offdiag) sobre 6 canales seleccionados.
# [INFO] Parámetros de normalización se calcularán usando 295 sujetos de entrenamiento.
# [INFO] Canal 'Pearson_Full_FisherZ_Signed': Off-diag zscore_offdiag (train_params: mean=-0.048, std=0.777)
# [INFO] Canal 'MI_KNN_Symmetric': Off-diag zscore_offdiag (train_params: mean=0.056, std=0.815)
# [INFO] Canal 'dFC_AbsDiffMean': Off-diag zscore_offdiag (train_params: mean=-0.037, std=0.767)
# [INFO] Canal 'dFC_StdDev': Off-diag zscore_offdiag (train_params: mean=0.035, std=0.715)
# [INFO] Canal 'DistanceCorr': Off-diag zscore_offdiag (train_params: mean=-0.402, std=1.628)
# [INFO] Canal 'Granger_F_lag1': Off-diag zscore_offdiag (train_params: mean=0.410, std=1.102)
# [INFO]   Fold 1/3 Usando dispositivo: cuda
# [INFO]   Fold 1/3 Usando scheduler: CosineAnnealingWarmRestarts (T_0=50)
# [INFO]   Fold 1/3 Entrenando VAE (Decoder: convtranspose, Encoder Layers: 4)...
# [INFO]   Fold 1/3 VAE E50/550, TrL: 100843.37 (R: 100228.41, KLD: 276.10), Beta: 2.227, LR: 1.04e-07, ValL: 101873.30 (R: 101350.73, KLD: 234.62)
# [INFO]   Fold 1/3 VAE E100/550, TrL: 87743.82 (R: 87217.17, KLD: 210.66), Beta: 2.500, LR: 1.04e-07, ValL: 88099.87 (R: 87669.16, KLD: 172.28)
# [INFO]   Fold 1/3 VAE E150/550, TrL: 82265.55 (R: 81681.03, KLD: 233.81), Beta: 2.500, LR: 1.04e-07, ValL: 83294.32 (R: 82836.61, KLD: 183.09)
# [INFO]   Fold 1/3 VAE E200/550, TrL: 78869.46 (R: 78671.82, KLD: 277.54), Beta: 0.712, LR: 1.04e-07, ValL: 80530.58 (R: 80377.88, KLD: 214.42)
# [INFO]   Fold 1/3 VAE E250/550, TrL: 77286.60 (R: 76498.40, KLD: 315.28), Beta: 2.500, LR: 1.04e-07, ValL: 79628.65 (R: 79064.55, KLD: 225.64)
# [INFO]   Fold 1/3 Early stopping VAE en epoch 257. Mejor val_loss: 79297.2924
# [INFO]   Fold 1/3 VAE final model loaded (best val_loss: 79297.2924).
# [INFO]   Fold 1/3 Modelo VAE guardado en: resultados_rfe_con_metadata/rfe_step_7_channels/ablation_Pearson_OMST_GCE_Signed_Weighted/fold_1/vae_model_fold_1.pt
# [INFO] Fold 1/3 Pool Train/Dev (Clasificador) (N=122):
#     ResearchGroup_Mapped:
#       AD: 63 (51.6%)
#       CN: 59 (48.4%)
#     Sex:
#       F: 60 (49.2%)
#       M: 62 (50.8%)
# [INFO]   Añadiendo metadatos al clasificador: ['Age', 'Sex']
# [INFO]   Forma final del set de entrenamiento del clasificador: (122, 514)
# [INFO]     --- Entrenando Clasificador: logreg ---
# [INFO] [SMOTE] ➜ Usando implementación de imblearn (CPU) para el clasificador 'logreg'.
# [INFO]       Mejores HPs para logreg: {'model__C': 0.00078441006675041}
# [INFO]       Modelo final (pipeline) para logreg listo.
# [INFO]       Resultados Fold 1 (logreg): AUC=0.7542, Bal.Acc=0.7240
# [INFO]       Pipeline completo de logreg del fold 1 guardado.
# [INFO]   Fold 1/3 completado en 143.42 segundos.
# [INFO] --- Iniciando Fold 2/3 ---
# [INFO] Fold 2/3 Test Set (Clasificador) (N=61):
#     ResearchGroup_Mapped:
#       AD: 31 (50.8%)
#       CN: 30 (49.2%)
#     Sex:
#       F: 30 (49.2%)
#       M: 31 (50.8%)
# [INFO] Fold 2/3 Pool Entrenamiento VAE (N=370):
#     ResearchGroup_Mapped:
#       AD: 64 (17.3%)
#       CN: 59 (15.9%)
#       MCI: 247 (66.8%)
#     Sex:
#       F: 176 (47.6%)
#       M: 194 (52.4%)
#     Age_Group:
#       0: 91 (24.6%)
#       1: 96 (25.9%)
#       2: 91 (24.6%)
#       3: 92 (24.9%)
# [INFO]   Fold 2/3 VAE val split será estratificado por ['ResearchGroup_Mapped', 'Sex', 'Age_Group'].
# [INFO] Fold 2/3 Actual Train Set (VAE) (N=296):
#     ResearchGroup_Mapped:
#       AD: 51 (17.2%)
#       CN: 47 (15.9%)
#       MCI: 198 (66.9%)
#     Sex:
#       F: 140 (47.3%)
#       M: 156 (52.7%)
#     Age_Group:
#       0: 73 (24.7%)
#       1: 78 (26.4%)
#       2: 72 (24.3%)
#       3: 73 (24.7%)
# [INFO] Fold 2/3 Internal Val Set (VAE) (N=74):
#     ResearchGroup_Mapped:
#       AD: 13 (17.6%)
#       CN: 12 (16.2%)
#       MCI: 49 (66.2%)
#     Sex:
#       F: 36 (48.6%)
#       M: 38 (51.4%)
#     Age_Group:
#       0: 18 (24.3%)
#       1: 18 (24.3%)
#       2: 19 (25.7%)
#       3: 19 (25.7%)
# [INFO]   Fold 2/3 Sujetos VAE actual train: 296, VAE internal val: 74
# [INFO] Aplicando normalización inter-canal (modo: zscore_offdiag) sobre 6 canales seleccionados.
# [INFO] Parámetros de normalización se calcularán usando 296 sujetos de entrenamiento.
# [INFO] Canal 'Pearson_Full_FisherZ_Signed': Off-diag zscore_offdiag (train_params: mean=-0.046, std=0.774)
# [INFO] Canal 'MI_KNN_Symmetric': Off-diag zscore_offdiag (train_params: mean=0.060, std=0.812)
# [INFO] Canal 'dFC_AbsDiffMean': Off-diag zscore_offdiag (train_params: mean=-0.035, std=0.766)
# [INFO] Canal 'dFC_StdDev': Off-diag zscore_offdiag (train_params: mean=0.034, std=0.714)
# [INFO] Canal 'DistanceCorr': Off-diag zscore_offdiag (train_params: mean=-0.401, std=1.689)
# [INFO] Canal 'Granger_F_lag1': Off-diag zscore_offdiag (train_params: mean=0.409, std=1.099)
# [INFO]   Fold 2/3 Usando dispositivo: cuda
# [INFO]   Fold 2/3 Usando scheduler: CosineAnnealingWarmRestarts (T_0=50)
# [INFO]   Fold 2/3 Entrenando VAE (Decoder: convtranspose, Encoder Layers: 4)...
# [INFO]   Fold 2/3 VAE E50/550, TrL: 98837.45 (R: 98135.86, KLD: 315.00), Beta: 2.227, LR: 1.04e-07, ValL: 96349.33 (R: 95748.09, KLD: 269.95)
# [INFO]   Fold 2/3 VAE E100/550, TrL: 87446.05 (R: 86874.85, KLD: 228.48), Beta: 2.500, LR: 1.04e-07, ValL: 84432.14 (R: 84004.78, KLD: 170.94)
# [INFO]   Fold 2/3 VAE E150/550, TrL: 82398.22 (R: 81785.84, KLD: 244.95), Beta: 2.500, LR: 1.04e-07, ValL: 80040.80 (R: 79593.22, KLD: 179.04)
# [INFO]   Fold 2/3 VAE E200/550, TrL: 79115.94 (R: 78917.30, KLD: 278.94), Beta: 0.712, LR: 1.04e-07, ValL: 77366.84 (R: 77218.69, KLD: 208.04)
# [INFO]   Fold 2/3 VAE E250/550, TrL: 77764.87 (R: 76971.30, KLD: 317.43), Beta: 2.500, LR: 1.04e-07, ValL: 76168.45 (R: 75623.67, KLD: 217.91)
# [INFO]   Fold 2/3 Early stopping VAE en epoch 252. Mejor val_loss: 76095.9909
# [INFO]   Fold 2/3 VAE final model loaded (best val_loss: 76095.9909).
# [INFO]   Fold 2/3 Modelo VAE guardado en: resultados_rfe_con_metadata/rfe_step_7_channels/ablation_Pearson_OMST_GCE_Signed_Weighted/fold_2/vae_model_fold_2.pt
# [INFO] Fold 2/3 Pool Train/Dev (Clasificador) (N=123):
#     ResearchGroup_Mapped:
#       AD: 64 (52.0%)
#       CN: 59 (48.0%)
#     Sex:
#       F: 62 (50.4%)
#       M: 61 (49.6%)
# [INFO]   Añadiendo metadatos al clasificador: ['Age', 'Sex']
# [INFO]   Forma final del set de entrenamiento del clasificador: (123, 514)
# [INFO]     --- Entrenando Clasificador: logreg ---
# [INFO] [SMOTE] ➜ Usando implementación de imblearn (CPU) para el clasificador 'logreg'.
# [INFO]       Mejores HPs para logreg: {'model__C': 0.0018849061195749866}
# [INFO]       Modelo final (pipeline) para logreg listo.
# [INFO]       Resultados Fold 2 (logreg): AUC=0.7925, Bal.Acc=0.7527
# [INFO]       Pipeline completo de logreg del fold 2 guardado.
# [INFO]   Fold 2/3 completado en 140.26 segundos.
# [INFO] --- Iniciando Fold 3/3 ---
# [INFO] Fold 3/3 Test Set (Clasificador) (N=61):
#     ResearchGroup_Mapped:
#       AD: 32 (52.5%)
#       CN: 29 (47.5%)
#     Sex:
#       F: 30 (49.2%)
#       M: 31 (50.8%)
# [INFO] Fold 3/3 Pool Entrenamiento VAE (N=370):
#     ResearchGroup_Mapped:
#       AD: 63 (17.0%)
#       CN: 60 (16.2%)
#       MCI: 247 (66.8%)
#     Sex:
#       F: 176 (47.6%)
#       M: 194 (52.4%)
#     Age_Group:
#       0: 94 (25.4%)
#       1: 95 (25.7%)
#       2: 94 (25.4%)
#       3: 87 (23.5%)
# [INFO]   Fold 3/3 VAE val split será estratificado por ['ResearchGroup_Mapped', 'Sex', 'Age_Group'].
# [INFO] Fold 3/3 Actual Train Set (VAE) (N=296):
#     ResearchGroup_Mapped:
#       AD: 50 (16.9%)
#       CN: 49 (16.6%)
#       MCI: 197 (66.6%)
#     Sex:
#       F: 142 (48.0%)
#       M: 154 (52.0%)
#     Age_Group:
#       0: 76 (25.7%)
#       1: 76 (25.7%)
#       2: 75 (25.3%)
#       3: 69 (23.3%)
# [INFO] Fold 3/3 Internal Val Set (VAE) (N=74):
#     ResearchGroup_Mapped:
#       AD: 13 (17.6%)
#       CN: 11 (14.9%)
#       MCI: 50 (67.6%)
#     Sex:
#       F: 34 (45.9%)
#       M: 40 (54.1%)
#     Age_Group:
#       0: 18 (24.3%)
#       1: 19 (25.7%)
#       2: 19 (25.7%)
#       3: 18 (24.3%)
# [INFO]   Fold 3/3 Sujetos VAE actual train: 296, VAE internal val: 74
# [INFO] Aplicando normalización inter-canal (modo: zscore_offdiag) sobre 6 canales seleccionados.
# [INFO] Parámetros de normalización se calcularán usando 296 sujetos de entrenamiento.
# [INFO] Canal 'Pearson_Full_FisherZ_Signed': Off-diag zscore_offdiag (train_params: mean=-0.051, std=0.780)
# [INFO] Canal 'MI_KNN_Symmetric': Off-diag zscore_offdiag (train_params: mean=0.053, std=0.813)
# [INFO] Canal 'dFC_AbsDiffMean': Off-diag zscore_offdiag (train_params: mean=-0.036, std=0.767)
# [INFO] Canal 'dFC_StdDev': Off-diag zscore_offdiag (train_params: mean=0.036, std=0.714)
# [INFO] Canal 'DistanceCorr': Off-diag zscore_offdiag (train_params: mean=-0.425, std=1.798)
# [INFO] Canal 'Granger_F_lag1': Off-diag zscore_offdiag (train_params: mean=0.409, std=1.101)
# [INFO]   Fold 3/3 Usando dispositivo: cuda
# [INFO]   Fold 3/3 Usando scheduler: CosineAnnealingWarmRestarts (T_0=50)
# [INFO]   Fold 3/3 Entrenando VAE (Decoder: convtranspose, Encoder Layers: 4)...
# [INFO]   Fold 3/3 VAE E50/550, TrL: 100213.12 (R: 99605.33, KLD: 272.89), Beta: 2.227, LR: 1.04e-07, ValL: 91853.66 (R: 91334.80, KLD: 232.96)
# [INFO]   Fold 3/3 VAE E100/550, TrL: 88098.70 (R: 87570.62, KLD: 211.23), Beta: 2.500, LR: 1.04e-07, ValL: 80019.91 (R: 79597.68, KLD: 168.89)
# [INFO]   Fold 3/3 VAE E150/550, TrL: 83244.55 (R: 82656.79, KLD: 235.10), Beta: 2.500, LR: 1.04e-07, ValL: 75771.91 (R: 75314.62, KLD: 182.91)
# [INFO]   Fold 3/3 VAE E200/550, TrL: 79823.94 (R: 79627.61, KLD: 275.70), Beta: 0.712, LR: 1.04e-07, ValL: 72682.70 (R: 72532.72, KLD: 210.61)
# [INFO]   Fold 3/3 VAE E250/550, TrL: 78126.24 (R: 77347.12, KLD: 311.65), Beta: 2.500, LR: 1.04e-07, ValL: 71536.92 (R: 70981.22, KLD: 222.28)
# [INFO]   Fold 3/3 VAE E300/550, TrL: 76466.82 (R: 75738.97, KLD: 291.14), Beta: 2.500, LR: 1.04e-07, ValL: 70328.66 (R: 69839.56, KLD: 195.64)
# [INFO]   Fold 3/3 VAE E350/550, TrL: 75219.49 (R: 74476.96, KLD: 297.01), Beta: 2.500, LR: 1.04e-07, ValL: 69724.11 (R: 69245.14, KLD: 191.58)
# [INFO]   Fold 3/3 VAE E400/550, TrL: 73800.67 (R: 73244.65, KLD: 378.32), Beta: 1.470, LR: 1.04e-07, ValL: 68802.26 (R: 68431.99, KLD: 251.94)
# [INFO]   Fold 3/3 Early stopping VAE en epoch 403. Mejor val_loss: 68675.8820
# [INFO]   Fold 3/3 VAE final model loaded (best val_loss: 68675.8820).
# [INFO]   Fold 3/3 Modelo VAE guardado en: resultados_rfe_con_metadata/rfe_step_7_channels/ablation_Pearson_OMST_GCE_Signed_Weighted/fold_3/vae_model_fold_3.pt
# [INFO] Fold 3/3 Pool Train/Dev (Clasificador) (N=123):
#     ResearchGroup_Mapped:
#       AD: 63 (51.2%)
#       CN: 60 (48.8%)
#     Sex:
#       F: 62 (50.4%)
#       M: 61 (49.6%)
# [INFO]   Añadiendo metadatos al clasificador: ['Age', 'Sex']
# [INFO]   Forma final del set de entrenamiento del clasificador: (123, 514)
# [INFO]     --- Entrenando Clasificador: logreg ---
# [INFO] [SMOTE] ➜ Usando implementación de imblearn (CPU) para el clasificador 'logreg'.
# [INFO]       Mejores HPs para logreg: {'model__C': 13.3032451015229}
# [INFO]       Modelo final (pipeline) para logreg listo.
# [INFO]       Resultados Fold 3 (logreg): AUC=0.6228, Bal.Acc=0.5711
# [INFO]       Pipeline completo de logreg del fold 3 guardado.
# [INFO]   Fold 3/3 completado en 217.03 segundos.
# [INFO]
# --- Resumen de Rendimiento para Clasificador: logreg (Promedio sobre Folds Externos) ---
# [INFO] Auc                 : 0.7232 +/- 0.0890
# [INFO] Pr_auc              : 0.7204 +/- 0.0798
# [INFO] Accuracy            : 0.6846 +/- 0.0970
# [INFO] Balanced_accuracy   : 0.6826 +/- 0.0976
# [INFO] Sensitivity         : 0.7483 +/- 0.1106
# [INFO] Specificity         : 0.6169 +/- 0.0863
# [INFO] F1_score            : 0.7095 +/- 0.0908
# [INFO] Resultados detallados de todos los clasificadores guardados en: resultados_rfe_con_metadata/rfe_step_7_channels/ablation_Pearson_OMST_GCE_Signed_Weighted/all_folds_metrics_MULTI_logreg_vaeconvtranspose4l_ld512_beta2.5_normzscore_offdiag_ch6sel_intFCquarter_drop0.2_ln0_outer3x1_scorebalanced_accuracy.csv
# [INFO] Sumario estadístico de métricas (por clasificador) guardado en: resultados_rfe_con_metadata/rfe_step_7_channels/ablation_Pearson_OMST_GCE_Signed_Weighted/summary_metrics_MULTI_logreg_vaeconvtranspose4l_ld512_beta2.5_normzscore_offdiag_ch6sel_intFCquarter_drop0.2_ln0_outer3x1_scorebalanced_accuracy.txt
# Ablación de 7 canales:  14%|███                  | 1/7 [08:20<50:05, 500.90s/it][INFO] Usando canales seleccionados (índices): [0, 2, 3, 4, 5, 6]
# [INFO] Nombres de canales seleccionados: ['Pearson_OMST_GCE_Signed_Weighted', 'MI_KNN_Symmetric', 'dFC_AbsDiffMean', 'dFC_StdDev', 'DistanceCorr', 'Granger_F_lag1']
# [INFO] Estratificando folds del CLASIFICADOR por: ['ResearchGroup_Mapped', 'Sex']
# [INFO] Sujetos CN/AD para clasificación: 184. CN: 89, AD: 95
# [INFO] Usando CV externa: StratifiedKFold con 3 iteraciones totales.
# [INFO] --- Iniciando Fold 1/3 ---
# [INFO] Fold 1/3 Test Set (Clasificador) (N=62):
#     ResearchGroup_Mapped:
#       AD: 32 (51.6%)
#       CN: 30 (48.4%)
#     Sex:
#       F: 32 (51.6%)
#       M: 30 (48.4%)
# [INFO] Fold 1/3 Pool Entrenamiento VAE (N=369):
#     ResearchGroup_Mapped:
#       AD: 63 (17.1%)
#       CN: 59 (16.0%)
#       MCI: 247 (66.9%)
#     Sex:
#       F: 174 (47.2%)
#       M: 195 (52.8%)
#     Age_Group:
#       0: 98 (26.6%)
#       1: 95 (25.7%)
#       2: 83 (22.5%)
#       3: 93 (25.2%)
# [INFO]   Fold 1/3 VAE val split será estratificado por ['ResearchGroup_Mapped', 'Sex', 'Age_Group'].
# [INFO] Fold 1/3 Actual Train Set (VAE) (N=295):
#     ResearchGroup_Mapped:
#       AD: 50 (16.9%)
#       CN: 48 (16.3%)
#       MCI: 197 (66.8%)
#     Sex:
#       F: 138 (46.8%)
#       M: 157 (53.2%)
#     Age_Group:
#       0: 79 (26.8%)
#       1: 76 (25.8%)
#       2: 66 (22.4%)
#       3: 74 (25.1%)
# [INFO] Fold 1/3 Internal Val Set (VAE) (N=74):
#     ResearchGroup_Mapped:
#       AD: 13 (17.6%)
#       CN: 11 (14.9%)
#       MCI: 50 (67.6%)
#     Sex:
#       F: 36 (48.6%)
#       M: 38 (51.4%)
#     Age_Group:
#       0: 19 (25.7%)
#       1: 19 (25.7%)
#       2: 17 (23.0%)
#       3: 19 (25.7%)
# [INFO]   Fold 1/3 Sujetos VAE actual train: 295, VAE internal val: 74
# [INFO] Aplicando normalización inter-canal (modo: zscore_offdiag) sobre 6 canales seleccionados.
# [INFO] Parámetros de normalización se calcularán usando 295 sujetos de entrenamiento.
# [INFO] Canal 'Pearson_OMST_GCE_Signed_Weighted': Off-diag zscore_offdiag (train_params: mean=0.310, std=1.091)
# [INFO] Canal 'MI_KNN_Symmetric': Off-diag zscore_offdiag (train_params: mean=0.056, std=0.815)
# [INFO] Canal 'dFC_AbsDiffMean': Off-diag zscore_offdiag (train_params: mean=-0.037, std=0.767)
# [INFO] Canal 'dFC_StdDev': Off-diag zscore_offdiag (train_params: mean=0.035, std=0.715)
# [INFO] Canal 'DistanceCorr': Off-diag zscore_offdiag (train_params: mean=-0.402, std=1.628)
# [INFO] Canal 'Granger_F_lag1': Off-diag zscore_offdiag (train_params: mean=0.410, std=1.102)
# [INFO]   Fold 1/3 Usando dispositivo: cuda
# [INFO]   Fold 1/3 Usando scheduler: CosineAnnealingWarmRestarts (T_0=50)
# [INFO]   Fold 1/3 Entrenando VAE (Decoder: convtranspose, Encoder Layers: 4)...
# [INFO]   Fold 1/3 VAE E50/550, TrL: 102923.41 (R: 102384.90, KLD: 241.78), Beta: 2.227, LR: 1.04e-07, ValL: 104385.40 (R: 103952.44, KLD: 194.39)
# [INFO]   Fold 1/3 VAE E100/550, TrL: 94532.53 (R: 94108.70, KLD: 169.53), Beta: 2.500, LR: 1.04e-07, ValL: 95852.03 (R: 95491.13, KLD: 144.36)
# [INFO]   Fold 1/3 VAE E150/550, TrL: 89589.58 (R: 89113.88, KLD: 190.28), Beta: 2.500, LR: 1.04e-07, ValL: 90922.80 (R: 90543.71, KLD: 151.63)
# [INFO]   Fold 1/3 VAE E200/550, TrL: 86274.51 (R: 86109.13, KLD: 232.24), Beta: 0.712, LR: 1.04e-07, ValL: 87794.31 (R: 87662.95, KLD: 184.46)
# [INFO]   Fold 1/3 VAE E250/550, TrL: 84477.82 (R: 83816.26, KLD: 264.62), Beta: 2.500, LR: 1.04e-07, ValL: 86362.75 (R: 85890.41, KLD: 188.94)
# [INFO]   Fold 1/3 VAE E300/550, TrL: 83051.79 (R: 82431.45, KLD: 248.14), Beta: 2.500, LR: 1.04e-07, ValL: 85127.48 (R: 84708.60, KLD: 167.55)
# [INFO]   Fold 1/3 VAE E350/550, TrL: 81821.56 (R: 81175.72, KLD: 258.33), Beta: 2.500, LR: 1.04e-07, ValL: 84247.93 (R: 83821.69, KLD: 170.50)
# [INFO]   Fold 1/3 Early stopping VAE en epoch 397. Mejor val_loss: 83221.9506
# [INFO]   Fold 1/3 VAE final model loaded (best val_loss: 83221.9506).
# [INFO]   Fold 1/3 Modelo VAE guardado en: resultados_rfe_con_metadata/rfe_step_7_channels/ablation_Pearson_Full_FisherZ_Signed/fold_1/vae_model_fold_1.pt
# [INFO] Fold 1/3 Pool Train/Dev (Clasificador) (N=122):
#     ResearchGroup_Mapped:
#       AD: 63 (51.6%)
#       CN: 59 (48.4%)
#     Sex:
#       F: 60 (49.2%)
#       M: 62 (50.8%)
# [INFO]   Añadiendo metadatos al clasificador: ['Age', 'Sex']
# [INFO]   Forma final del set de entrenamiento del clasificador: (122, 514)
# [INFO]     --- Entrenando Clasificador: logreg ---
# [INFO] [SMOTE] ➜ Usando implementación de imblearn (CPU) para el clasificador 'logreg'.
# [INFO]       Mejores HPs para logreg: {'model__C': 0.015115319924378076}
# [INFO]       Modelo final (pipeline) para logreg listo.
# [INFO]       Resultados Fold 1 (logreg): AUC=0.7344, Bal.Acc=0.6927
# [INFO]       Pipeline completo de logreg del fold 1 guardado.
# [INFO]   Fold 1/3 completado en 212.66 segundos.
# [INFO] --- Iniciando Fold 2/3 ---
# [INFO] Fold 2/3 Test Set (Clasificador) (N=61):
#     ResearchGroup_Mapped:
#       AD: 31 (50.8%)
#       CN: 30 (49.2%)
#     Sex:
#       F: 30 (49.2%)
#       M: 31 (50.8%)
# [INFO] Fold 2/3 Pool Entrenamiento VAE (N=370):
#     ResearchGroup_Mapped:
#       AD: 64 (17.3%)
#       CN: 59 (15.9%)
#       MCI: 247 (66.8%)
#     Sex:
#       F: 176 (47.6%)
#       M: 194 (52.4%)
#     Age_Group:
#       0: 91 (24.6%)
#       1: 96 (25.9%)
#       2: 91 (24.6%)
#       3: 92 (24.9%)
# [INFO]   Fold 2/3 VAE val split será estratificado por ['ResearchGroup_Mapped', 'Sex', 'Age_Group'].
# [INFO] Fold 2/3 Actual Train Set (VAE) (N=296):
#     ResearchGroup_Mapped:
#       AD: 51 (17.2%)
#       CN: 47 (15.9%)
#       MCI: 198 (66.9%)
#     Sex:
#       F: 140 (47.3%)
#       M: 156 (52.7%)
#     Age_Group:
#       0: 73 (24.7%)
#       1: 78 (26.4%)
#       2: 72 (24.3%)
#       3: 73 (24.7%)
# [INFO] Fold 2/3 Internal Val Set (VAE) (N=74):
#     ResearchGroup_Mapped:
#       AD: 13 (17.6%)
#       CN: 12 (16.2%)
#       MCI: 49 (66.2%)
#     Sex:
#       F: 36 (48.6%)
#       M: 38 (51.4%)
#     Age_Group:
#       0: 18 (24.3%)
#       1: 18 (24.3%)
#       2: 19 (25.7%)
#       3: 19 (25.7%)
# [INFO]   Fold 2/3 Sujetos VAE actual train: 296, VAE internal val: 74
# [INFO] Aplicando normalización inter-canal (modo: zscore_offdiag) sobre 6 canales seleccionados.
# [INFO] Parámetros de normalización se calcularán usando 296 sujetos de entrenamiento.
# [INFO] Canal 'Pearson_OMST_GCE_Signed_Weighted': Off-diag zscore_offdiag (train_params: mean=0.309, std=1.090)
# [INFO] Canal 'MI_KNN_Symmetric': Off-diag zscore_offdiag (train_params: mean=0.060, std=0.812)
# [INFO] Canal 'dFC_AbsDiffMean': Off-diag zscore_offdiag (train_params: mean=-0.035, std=0.766)
# [INFO] Canal 'dFC_StdDev': Off-diag zscore_offdiag (train_params: mean=0.034, std=0.714)
# [INFO] Canal 'DistanceCorr': Off-diag zscore_offdiag (train_params: mean=-0.401, std=1.689)
# [INFO] Canal 'Granger_F_lag1': Off-diag zscore_offdiag (train_params: mean=0.409, std=1.099)
# [INFO]   Fold 2/3 Usando dispositivo: cuda
# [INFO]   Fold 2/3 Usando scheduler: CosineAnnealingWarmRestarts (T_0=50)
# [INFO]   Fold 2/3 Entrenando VAE (Decoder: convtranspose, Encoder Layers: 4)...
# [INFO]   Fold 2/3 VAE E50/550, TrL: 103164.79 (R: 102607.81, KLD: 250.07), Beta: 2.227, LR: 1.04e-07, ValL: 103108.66 (R: 102666.50, KLD: 198.52)
# [INFO]   Fold 2/3 VAE E100/550, TrL: 94568.79 (R: 94096.68, KLD: 188.84), Beta: 2.500, LR: 1.04e-07, ValL: 93269.70 (R: 92917.11, KLD: 141.04)
# [INFO]   Fold 2/3 VAE E150/550, TrL: 89968.46 (R: 89464.78, KLD: 201.47), Beta: 2.500, LR: 1.04e-07, ValL: 88666.71 (R: 88304.05, KLD: 145.06)
# [INFO]   Fold 2/3 VAE E200/550, TrL: 86567.77 (R: 86395.77, KLD: 241.52), Beta: 0.712, LR: 1.04e-07, ValL: 85636.07 (R: 85512.20, KLD: 173.95)
# [INFO]   Fold 2/3 VAE E250/550, TrL: 84833.29 (R: 84146.50, KLD: 274.71), Beta: 2.500, LR: 1.04e-07, ValL: 84110.01 (R: 83655.94, KLD: 181.63)
# [INFO]   Fold 2/3 VAE E300/550, TrL: 83160.91 (R: 82519.41, KLD: 256.60), Beta: 2.500, LR: 1.04e-07, ValL: 82844.65 (R: 82442.26, KLD: 160.96)
# [INFO]   Fold 2/3 VAE E350/550, TrL: 81805.38 (R: 81136.94, KLD: 267.38), Beta: 2.500, LR: 1.04e-07, ValL: 81987.38 (R: 81579.37, KLD: 163.20)
# [INFO]   Fold 2/3 VAE E400/550, TrL: 80387.70 (R: 79868.60, KLD: 353.20), Beta: 1.470, LR: 1.04e-07, ValL: 81050.99 (R: 80727.44, KLD: 220.15)
# [INFO]   Fold 2/3 Early stopping VAE en epoch 401. Mejor val_loss: 80884.1780
# [INFO]   Fold 2/3 VAE final model loaded (best val_loss: 80884.1780).
# [INFO]   Fold 2/3 Modelo VAE guardado en: resultados_rfe_con_metadata/rfe_step_7_channels/ablation_Pearson_Full_FisherZ_Signed/fold_2/vae_model_fold_2.pt
# [INFO] Fold 2/3 Pool Train/Dev (Clasificador) (N=123):
#     ResearchGroup_Mapped:
#       AD: 64 (52.0%)
#       CN: 59 (48.0%)
#     Sex:
#       F: 62 (50.4%)
#       M: 61 (49.6%)
# [INFO]   Añadiendo metadatos al clasificador: ['Age', 'Sex']
# [INFO]   Forma final del set de entrenamiento del clasificador: (123, 514)
# [INFO]     --- Entrenando Clasificador: logreg ---
# [INFO] [SMOTE] ➜ Usando implementación de imblearn (CPU) para el clasificador 'logreg'.
# [INFO]       Mejores HPs para logreg: {'model__C': 0.028731536456492728}
# [INFO]       Modelo final (pipeline) para logreg listo.
# [INFO]       Resultados Fold 2 (logreg): AUC=0.7151, Bal.Acc=0.5909
# [INFO]       Pipeline completo de logreg del fold 2 guardado.
# [INFO]   Fold 2/3 completado en 218.75 segundos.
# [INFO] --- Iniciando Fold 3/3 ---
# [INFO] Fold 3/3 Test Set (Clasificador) (N=61):
#     ResearchGroup_Mapped:
#       AD: 32 (52.5%)
#       CN: 29 (47.5%)
#     Sex:
#       F: 30 (49.2%)
#       M: 31 (50.8%)
# [INFO] Fold 3/3 Pool Entrenamiento VAE (N=370):
#     ResearchGroup_Mapped:
#       AD: 63 (17.0%)
#       CN: 60 (16.2%)
#       MCI: 247 (66.8%)
#     Sex:
#       F: 176 (47.6%)
#       M: 194 (52.4%)
#     Age_Group:
#       0: 94 (25.4%)
#       1: 95 (25.7%)
#       2: 94 (25.4%)
#       3: 87 (23.5%)
# [INFO]   Fold 3/3 VAE val split será estratificado por ['ResearchGroup_Mapped', 'Sex', 'Age_Group'].
# [INFO] Fold 3/3 Actual Train Set (VAE) (N=296):
#     ResearchGroup_Mapped:
#       AD: 50 (16.9%)
#       CN: 49 (16.6%)
#       MCI: 197 (66.6%)
#     Sex:
#       F: 142 (48.0%)
#       M: 154 (52.0%)
#     Age_Group:
#       0: 76 (25.7%)
#       1: 76 (25.7%)
#       2: 75 (25.3%)
#       3: 69 (23.3%)
# [INFO] Fold 3/3 Internal Val Set (VAE) (N=74):
#     ResearchGroup_Mapped:
#       AD: 13 (17.6%)
#       CN: 11 (14.9%)
#       MCI: 50 (67.6%)
#     Sex:
#       F: 34 (45.9%)
#       M: 40 (54.1%)
#     Age_Group:
#       0: 18 (24.3%)
#       1: 19 (25.7%)
#       2: 19 (25.7%)
#       3: 18 (24.3%)
# [INFO]   Fold 3/3 Sujetos VAE actual train: 296, VAE internal val: 74
# [INFO] Aplicando normalización inter-canal (modo: zscore_offdiag) sobre 6 canales seleccionados.
# [INFO] Parámetros de normalización se calcularán usando 296 sujetos de entrenamiento.
# [INFO] Canal 'Pearson_OMST_GCE_Signed_Weighted': Off-diag zscore_offdiag (train_params: mean=0.309, std=1.092)
# [INFO] Canal 'MI_KNN_Symmetric': Off-diag zscore_offdiag (train_params: mean=0.053, std=0.813)
# [INFO] Canal 'dFC_AbsDiffMean': Off-diag zscore_offdiag (train_params: mean=-0.036, std=0.767)
# [INFO] Canal 'dFC_StdDev': Off-diag zscore_offdiag (train_params: mean=0.036, std=0.714)
# [INFO] Canal 'DistanceCorr': Off-diag zscore_offdiag (train_params: mean=-0.425, std=1.798)
# [INFO] Canal 'Granger_F_lag1': Off-diag zscore_offdiag (train_params: mean=0.409, std=1.101)
# [INFO]   Fold 3/3 Usando dispositivo: cuda
# [INFO]   Fold 3/3 Usando scheduler: CosineAnnealingWarmRestarts (T_0=50)
# [INFO]   Fold 3/3 Entrenando VAE (Decoder: convtranspose, Encoder Layers: 4)...
# [INFO]   Fold 3/3 VAE E50/550, TrL: 102394.10 (R: 101786.94, KLD: 272.60), Beta: 2.227, LR: 1.04e-07, ValL: 94390.41 (R: 93848.73, KLD: 243.20)
# [INFO]   Fold 3/3 VAE E100/550, TrL: 94032.08 (R: 93566.57, KLD: 186.20), Beta: 2.500, LR: 1.04e-07, ValL: 86143.83 (R: 85771.19, KLD: 149.05)
# [INFO]   Fold 3/3 VAE E150/550, TrL: 89678.82 (R: 89183.51, KLD: 198.12), Beta: 2.500, LR: 1.04e-07, ValL: 81857.55 (R: 81488.82, KLD: 147.49)
# [INFO]   Fold 3/3 VAE E200/550, TrL: 86539.44 (R: 86372.79, KLD: 234.02), Beta: 0.712, LR: 1.04e-07, ValL: 78996.86 (R: 78875.03, KLD: 171.08)
# [INFO]   Fold 3/3 VAE E250/550, TrL: 85073.97 (R: 84415.42, KLD: 263.42), Beta: 2.500, LR: 1.04e-07, ValL: 77515.79 (R: 77074.32, KLD: 176.59)
# [INFO]   Fold 3/3 VAE E300/550, TrL: 83511.52 (R: 82896.49, KLD: 246.01), Beta: 2.500, LR: 1.04e-07, ValL: 76243.25 (R: 75850.96, KLD: 156.92)
# [INFO]   Fold 3/3 VAE E350/550, TrL: 82324.96 (R: 81682.14, KLD: 257.13), Beta: 2.500, LR: 1.04e-07, ValL: 75275.58 (R: 74886.79, KLD: 155.52)
# [INFO]   Fold 3/3 Early stopping VAE en epoch 400. Mejor val_loss: 74206.9770
# [INFO]   Fold 3/3 VAE final model loaded (best val_loss: 74206.9770).
# [INFO]   Fold 3/3 Modelo VAE guardado en: resultados_rfe_con_metadata/rfe_step_7_channels/ablation_Pearson_Full_FisherZ_Signed/fold_3/vae_model_fold_3.pt
# [INFO] Fold 3/3 Pool Train/Dev (Clasificador) (N=123):
#     ResearchGroup_Mapped:
#       AD: 63 (51.2%)
#       CN: 60 (48.8%)
#     Sex:
#       F: 62 (50.4%)
#       M: 61 (49.6%)
# [INFO]   Añadiendo metadatos al clasificador: ['Age', 'Sex']
# [INFO]   Forma final del set de entrenamiento del clasificador: (123, 514)
# [INFO]     --- Entrenando Clasificador: logreg ---
# [INFO] [SMOTE] ➜ Usando implementación de imblearn (CPU) para el clasificador 'logreg'.
# [INFO]       Mejores HPs para logreg: {'model__C': 0.08922249305565962}
# [INFO]       Modelo final (pipeline) para logreg listo.
# [INFO]       Resultados Fold 3 (logreg): AUC=0.6218, Bal.Acc=0.6040
# [INFO]       Pipeline completo de logreg del fold 3 guardado.
# [INFO]   Fold 3/3 completado en 216.62 segundos.
# [INFO]
# --- Resumen de Rendimiento para Clasificador: logreg (Promedio sobre Folds Externos) ---
# [INFO] Auc                 : 0.6904 +/- 0.0602
# [INFO] Pr_auc              : 0.6617 +/- 0.0674
# [INFO] Accuracy            : 0.6301 +/- 0.0556
# [INFO] Balanced_accuracy   : 0.6292 +/- 0.0554
# [INFO] Sensitivity         : 0.6411 +/- 0.0862
# [INFO] Specificity         : 0.6172 +/- 0.0591
# [INFO] F1_score            : 0.6401 +/- 0.0658
# [INFO] Resultados detallados de todos los clasificadores guardados en: resultados_rfe_con_metadata/rfe_step_7_channels/ablation_Pearson_Full_FisherZ_Signed/all_folds_metrics_MULTI_logreg_vaeconvtranspose4l_ld512_beta2.5_normzscore_offdiag_ch6sel_intFCquarter_drop0.2_ln0_outer3x1_scorebalanced_accuracy.csv
# [INFO] Sumario estadístico de métricas (por clasificador) guardado en: resultados_rfe_con_metadata/rfe_step_7_channels/ablation_Pearson_Full_FisherZ_Signed/summary_metrics_MULTI_logreg_vaeconvtranspose4l_ld512_beta2.5_normzscore_offdiag_ch6sel_intFCquarter_drop0.2_ln0_outer3x1_scorebalanced_accuracy.txt
# Ablación de 7 canales:  29%|██████               | 2/7 [19:09<48:57, 587.56s/it][INFO] Usando canales seleccionados (índices): [0, 1, 3, 4, 5, 6]
# [INFO] Nombres de canales seleccionados: ['Pearson_OMST_GCE_Signed_Weighted', 'Pearson_Full_FisherZ_Signed', 'dFC_AbsDiffMean', 'dFC_StdDev', 'DistanceCorr', 'Granger_F_lag1']
# [INFO] Estratificando folds del CLASIFICADOR por: ['ResearchGroup_Mapped', 'Sex']
# [INFO] Sujetos CN/AD para clasificación: 184. CN: 89, AD: 95
# [INFO] Usando CV externa: StratifiedKFold con 3 iteraciones totales.
# [INFO] --- Iniciando Fold 1/3 ---
# [INFO] Fold 1/3 Test Set (Clasificador) (N=62):
#     ResearchGroup_Mapped:
#       AD: 32 (51.6%)
#       CN: 30 (48.4%)
#     Sex:
#       F: 32 (51.6%)
#       M: 30 (48.4%)
# [INFO] Fold 1/3 Pool Entrenamiento VAE (N=369):
#     ResearchGroup_Mapped:
#       AD: 63 (17.1%)
#       CN: 59 (16.0%)
#       MCI: 247 (66.9%)
#     Sex:
#       F: 174 (47.2%)
#       M: 195 (52.8%)
#     Age_Group:
#       0: 98 (26.6%)
#       1: 95 (25.7%)
#       2: 83 (22.5%)
#       3: 93 (25.2%)
# [INFO]   Fold 1/3 VAE val split será estratificado por ['ResearchGroup_Mapped', 'Sex', 'Age_Group'].
# [INFO] Fold 1/3 Actual Train Set (VAE) (N=295):
#     ResearchGroup_Mapped:
#       AD: 50 (16.9%)
#       CN: 48 (16.3%)
#       MCI: 197 (66.8%)
#     Sex:
#       F: 138 (46.8%)
#       M: 157 (53.2%)
#     Age_Group:
#       0: 79 (26.8%)
#       1: 76 (25.8%)
#       2: 66 (22.4%)
#       3: 74 (25.1%)
# [INFO] Fold 1/3 Internal Val Set (VAE) (N=74):
#     ResearchGroup_Mapped:
#       AD: 13 (17.6%)
#       CN: 11 (14.9%)
#       MCI: 50 (67.6%)
#     Sex:
#       F: 36 (48.6%)
#       M: 38 (51.4%)
#     Age_Group:
#       0: 19 (25.7%)
#       1: 19 (25.7%)
#       2: 17 (23.0%)
#       3: 19 (25.7%)
# [INFO]   Fold 1/3 Sujetos VAE actual train: 295, VAE internal val: 74
# [INFO] Aplicando normalización inter-canal (modo: zscore_offdiag) sobre 6 canales seleccionados.
# [INFO] Parámetros de normalización se calcularán usando 295 sujetos de entrenamiento.
# [INFO] Canal 'Pearson_OMST_GCE_Signed_Weighted': Off-diag zscore_offdiag (train_params: mean=0.310, std=1.091)
# [INFO] Canal 'Pearson_Full_FisherZ_Signed': Off-diag zscore_offdiag (train_params: mean=-0.048, std=0.777)
# [INFO] Canal 'dFC_AbsDiffMean': Off-diag zscore_offdiag (train_params: mean=-0.037, std=0.767)
# [INFO] Canal 'dFC_StdDev': Off-diag zscore_offdiag (train_params: mean=0.035, std=0.715)
# [INFO] Canal 'DistanceCorr': Off-diag zscore_offdiag (train_params: mean=-0.402, std=1.628)
# [INFO] Canal 'Granger_F_lag1': Off-diag zscore_offdiag (train_params: mean=0.410, std=1.102)
# [INFO]   Fold 1/3 Usando dispositivo: cuda
# [INFO]   Fold 1/3 Usando scheduler: CosineAnnealingWarmRestarts (T_0=50)
# [INFO]   Fold 1/3 Entrenando VAE (Decoder: convtranspose, Encoder Layers: 4)...
# [INFO]   Fold 1/3 VAE E50/550, TrL: 101809.84 (R: 101222.83, KLD: 263.56), Beta: 2.227, LR: 1.04e-07, ValL: 102984.87 (R: 102559.85, KLD: 190.83)
# [INFO]   Fold 1/3 VAE E100/550, TrL: 91881.32 (R: 91410.17, KLD: 188.46), Beta: 2.500, LR: 1.04e-07, ValL: 92438.64 (R: 92070.63, KLD: 147.20)
# [INFO]   Fold 1/3 VAE E150/550, TrL: 87446.61 (R: 86955.01, KLD: 196.64), Beta: 2.500, LR: 1.04e-07, ValL: 88346.76 (R: 87964.30, KLD: 152.98)
# [INFO]   Fold 1/3 VAE E200/550, TrL: 84418.06 (R: 84250.91, KLD: 234.73), Beta: 0.712, LR: 1.04e-07, ValL: 85621.42 (R: 85494.76, KLD: 177.86)
# [INFO]   Fold 1/3 VAE E250/550, TrL: 82871.64 (R: 82227.57, KLD: 257.63), Beta: 2.500, LR: 1.04e-07, ValL: 84402.81 (R: 83947.24, KLD: 182.23)
# [INFO]   Fold 1/3 VAE E300/550, TrL: 81414.88 (R: 80794.04, KLD: 248.34), Beta: 2.500, LR: 1.04e-07, ValL: 83285.32 (R: 82874.37, KLD: 164.38)
# ...
# [INFO]   Fold 3/3 Usando scheduler: CosineAnnealingWarmRestarts (T_0=50)
# [INFO]   Fold 3/3 Entrenando VAE (Decoder: convtranspose, Encoder Layers: 4)...
# [INFO]   Fold 3/3 VAE E50/550, TrL: 13935.55 (R: 13418.85, KLD: 231.99), Beta: 2.227, LR: 1.04e-07, ValL: 12221.20 (R: 11611.43, KLD: 273.78)
# [INFO]   Fold 3/3 VAE E100/550, TrL: 11233.90 (R: 10915.88, KLD: 127.21), Beta: 2.500, LR: 1.04e-07, ValL: 9866.15 (R: 9587.26, KLD: 111.56)
# [INFO]   Fold 3/3 VAE E150/550, TrL: 10269.19 (R: 9944.56, KLD: 129.85), Beta: 2.500, LR: 1.04e-07, ValL: 9091.99 (R: 8823.15, KLD: 107.54)
# [INFO]   Fold 3/3 VAE E200/550, TrL: 9393.84 (R: 9280.34, KLD: 159.39), Beta: 0.712, LR: 1.04e-07, ValL: 8474.01 (R: 8375.28, KLD: 138.63)
# [INFO]   Fold 3/3 Early stopping VAE en epoch 206. Mejor val_loss: 8393.8681
# [INFO]   Fold 3/3 VAE final model loaded (best val_loss: 8393.8681).
# [INFO]   Fold 3/3 Modelo VAE guardado en: resultados_rfe_con_metadata/rfe_step_2_channels/ablation_DistanceCorr/fold_3/vae_model_fold_3.pt
# [INFO] Fold 3/3 Pool Train/Dev (Clasificador) (N=123):
#     ResearchGroup_Mapped:
#       AD: 63 (51.2%)
#       CN: 60 (48.8%)
#     Sex:
#       F: 62 (50.4%)
#       M: 61 (49.6%)
# [INFO]   Añadiendo metadatos al clasificador: ['Age', 'Sex']
# [INFO]   Forma final del set de entrenamiento del clasificador: (123, 514)
# [INFO]     --- Entrenando Clasificador: logreg ---
# [INFO] [SMOTE] ➜ Usando implementación de imblearn (CPU) para el clasificador 'logreg'.
# [INFO]       Mejores HPs para logreg: {'model__C': 0.0018849061195749866}
# [INFO]       Modelo final (pipeline) para logreg listo.
# [INFO]       Resultados Fold 3 (logreg): AUC=0.7284, Bal.Acc=0.6665
# [INFO]       Pipeline completo de logreg del fold 3 guardado.
# [INFO]   Fold 3/3 completado en 105.10 segundos.
# [INFO]
# --- Resumen de Rendimiento para Clasificador: logreg (Promedio sobre Folds Externos) ---
# [INFO] Auc                 : 0.7998 +/- 0.0692
# [INFO] Pr_auc              : 0.7870 +/- 0.0707
# [INFO] Accuracy            : 0.7282 +/- 0.0506
# [INFO] Balanced_accuracy   : 0.7256 +/- 0.0527
# [INFO] Sensitivity         : 0.8118 +/- 0.1116
# [INFO] Specificity         : 0.6395 +/- 0.1128
# [INFO] F1_score            : 0.7539 +/- 0.0468
# [INFO] Resultados detallados de todos los clasificadores guardados en: resultados_rfe_con_metadata/rfe_step_2_channels/ablation_DistanceCorr/all_folds_metrics_MULTI_logreg_vaeconvtranspose4l_ld512_beta2.5_normzscore_offdiag_ch1sel_intFCquarter_drop0.2_ln0_outer3x1_scorebalanced_accuracy.csv
# [INFO] Sumario estadístico de métricas (por clasificador) guardado en: resultados_rfe_con_metadata/rfe_step_2_channels/ablation_DistanceCorr/summary_metrics_MULTI_logreg_vaeconvtranspose4l_ld512_beta2.5_normzscore_offdiag_ch1sel_intFCquarter_drop0.2_ln0_outer3x1_scorebalanced_accuracy.txt
# Ablación de 2 canales: 100%|█████████████████████| 2/2 [10:28<00:00, 314.32s/it]
# [INFO] Progreso de RFE guardado en: resultados_rfe_con_metadata/rfe_summary.csv
# [INFO] El mejor candidato para eliminar es 'DistanceCorr', ya que su eliminación cambia el rendimiento en 0.0075
# [INFO] --- Evaluando el último canal restante: Pearson_Full_FisherZ_Signed ---
# [INFO] Usando canales seleccionados (índices): [1]
# [INFO] Nombres de canales seleccionados: ['Pearson_Full_FisherZ_Signed']
# [INFO] Estratificando folds del CLASIFICADOR por: ['ResearchGroup_Mapped', 'Sex']
# [INFO] Sujetos CN/AD para clasificación: 184. CN: 89, AD: 95
# [INFO] Usando CV externa: StratifiedKFold con 3 iteraciones totales.
# [INFO] --- Iniciando Fold 1/3 ---
# [INFO] Fold 1/3 Test Set (Clasificador) (N=62):
#     ResearchGroup_Mapped:
#       AD: 32 (51.6%)
#       CN: 30 (48.4%)
#     Sex:
#       F: 32 (51.6%)
#       M: 30 (48.4%)
# [INFO] Fold 1/3 Pool Entrenamiento VAE (N=369):
#     ResearchGroup_Mapped:
#       AD: 63 (17.1%)
#       CN: 59 (16.0%)
#       MCI: 247 (66.9%)
#     Sex:
#       F: 174 (47.2%)
#       M: 195 (52.8%)
#     Age_Group:
#       0: 98 (26.6%)
#       1: 95 (25.7%)
#       2: 83 (22.5%)
#       3: 93 (25.2%)
# [INFO]   Fold 1/3 VAE val split será estratificado por ['ResearchGroup_Mapped', 'Sex', 'Age_Group'].
# [INFO] Fold 1/3 Actual Train Set (VAE) (N=295):
#     ResearchGroup_Mapped:
#       AD: 50 (16.9%)
#       CN: 48 (16.3%)
#       MCI: 197 (66.8%)
#     Sex:
#       F: 138 (46.8%)
#       M: 157 (53.2%)
#     Age_Group:
#       0: 79 (26.8%)
#       1: 76 (25.8%)
#       2: 66 (22.4%)
#       3: 74 (25.1%)
# [INFO] Fold 1/3 Internal Val Set (VAE) (N=74):
#     ResearchGroup_Mapped:
#       AD: 13 (17.6%)
#       CN: 11 (14.9%)
#       MCI: 50 (67.6%)
#     Sex:
#       F: 36 (48.6%)
#       M: 38 (51.4%)
#     Age_Group:
#       0: 19 (25.7%)
#       1: 19 (25.7%)
#       2: 17 (23.0%)
#       3: 19 (25.7%)
# [INFO]   Fold 1/3 Sujetos VAE actual train: 295, VAE internal val: 74
# [INFO] Aplicando normalización inter-canal (modo: zscore_offdiag) sobre 1 canales seleccionados.
# [INFO] Parámetros de normalización se calcularán usando 295 sujetos de entrenamiento.
# [INFO] Canal 'Pearson_Full_FisherZ_Signed': Off-diag zscore_offdiag (train_params: mean=-0.048, std=0.777)
# [INFO]   Fold 1/3 Usando dispositivo: cuda
# [INFO]   Fold 1/3 Usando scheduler: CosineAnnealingWarmRestarts (T_0=50)
# [INFO]   Fold 1/3 Entrenando VAE (Decoder: convtranspose, Encoder Layers: 4)...
# [INFO]   Fold 1/3 VAE E50/550, TrL: 13873.67 (R: 13350.86, KLD: 234.73), Beta: 2.227, LR: 1.04e-07, ValL: 12456.85 (R: 11941.17, KLD: 231.53)
# [INFO]   Fold 1/3 VAE E100/550, TrL: 11261.07 (R: 10940.43, KLD: 128.26), Beta: 2.500, LR: 1.04e-07, ValL: 10153.20 (R: 9888.59, KLD: 105.85)
# [INFO]   Fold 1/3 VAE E150/550, TrL: 10227.65 (R: 9901.27, KLD: 130.55), Beta: 2.500, LR: 1.04e-07, ValL: 9292.03 (R: 9029.09, KLD: 105.17)
# [INFO]   Fold 1/3 VAE E200/550, TrL: 9423.31 (R: 9308.99, KLD: 160.53), Beta: 0.712, LR: 1.04e-07, ValL: 8627.78 (R: 8529.00, KLD: 138.71)
# [INFO]   Fold 1/3 Early stopping VAE en epoch 206. Mejor val_loss: 8554.3563
# [INFO]   Fold 1/3 VAE final model loaded (best val_loss: 8554.3563).
# [INFO]   Fold 1/3 Modelo VAE guardado en: resultados_rfe_con_metadata/rfe_step_1_channel/fold_1/vae_model_fold_1.pt
# [INFO] Fold 1/3 Pool Train/Dev (Clasificador) (N=122):
#     ResearchGroup_Mapped:
#       AD: 63 (51.6%)
#       CN: 59 (48.4%)
#     Sex:
#       F: 60 (49.2%)
#       M: 62 (50.8%)
# [INFO]   Añadiendo metadatos al clasificador: ['Age', 'Sex']
# [INFO]   Forma final del set de entrenamiento del clasificador: (122, 514)
# [INFO]     --- Entrenando Clasificador: logreg ---
# [INFO] [SMOTE] ➜ Usando implementación de imblearn (CPU) para el clasificador 'logreg'.
# [INFO]       Mejores HPs para logreg: {'model__C': 0.004662721563074291}
# [INFO]       Modelo final (pipeline) para logreg listo.
# [INFO]       Resultados Fold 1 (logreg): AUC=0.8042, Bal.Acc=0.7417
# [INFO]       Pipeline completo de logreg del fold 1 guardado.
# [INFO]   Fold 1/3 completado en 103.37 segundos.
# [INFO] --- Iniciando Fold 2/3 ---
# [INFO] Fold 2/3 Test Set (Clasificador) (N=61):
#     ResearchGroup_Mapped:
#       AD: 31 (50.8%)
#       CN: 30 (49.2%)
#     Sex:
#       F: 30 (49.2%)
#       M: 31 (50.8%)
# [INFO] Fold 2/3 Pool Entrenamiento VAE (N=370):
#     ResearchGroup_Mapped:
#       AD: 64 (17.3%)
#       CN: 59 (15.9%)
#       MCI: 247 (66.8%)
#     Sex:
#       F: 176 (47.6%)
#       M: 194 (52.4%)
#     Age_Group:
#       0: 91 (24.6%)
#       1: 96 (25.9%)
#       2: 91 (24.6%)
#       3: 92 (24.9%)
# [INFO]   Fold 2/3 VAE val split será estratificado por ['ResearchGroup_Mapped', 'Sex', 'Age_Group'].
# [INFO] Fold 2/3 Actual Train Set (VAE) (N=296):
#     ResearchGroup_Mapped:
#       AD: 51 (17.2%)
#       CN: 47 (15.9%)
#       MCI: 198 (66.9%)
#     Sex:
#       F: 140 (47.3%)
#       M: 156 (52.7%)
#     Age_Group:
#       0: 73 (24.7%)
#       1: 78 (26.4%)
#       2: 72 (24.3%)
#       3: 73 (24.7%)
# [INFO] Fold 2/3 Internal Val Set (VAE) (N=74):
#     ResearchGroup_Mapped:
#       AD: 13 (17.6%)
#       CN: 12 (16.2%)
#       MCI: 49 (66.2%)
#     Sex:
#       F: 36 (48.6%)
#       M: 38 (51.4%)
#     Age_Group:
#       0: 18 (24.3%)
#       1: 18 (24.3%)
#       2: 19 (25.7%)
#       3: 19 (25.7%)
# [INFO]   Fold 2/3 Sujetos VAE actual train: 296, VAE internal val: 74
# [INFO] Aplicando normalización inter-canal (modo: zscore_offdiag) sobre 1 canales seleccionados.
# [INFO] Parámetros de normalización se calcularán usando 296 sujetos de entrenamiento.
# [INFO] Canal 'Pearson_Full_FisherZ_Signed': Off-diag zscore_offdiag (train_params: mean=-0.046, std=0.774)
# [INFO]   Fold 2/3 Usando dispositivo: cuda
# [INFO]   Fold 2/3 Usando scheduler: CosineAnnealingWarmRestarts (T_0=50)
# [INFO]   Fold 2/3 Entrenando VAE (Decoder: convtranspose, Encoder Layers: 4)...
# [INFO]   Fold 2/3 VAE E50/550, TrL: 13449.78 (R: 12926.27, KLD: 235.05), Beta: 2.227, LR: 1.04e-07, ValL: 11939.06 (R: 11501.28, KLD: 196.56)
# [INFO]   Fold 2/3 VAE E100/550, TrL: 11085.87 (R: 10757.16, KLD: 131.48), Beta: 2.500, LR: 1.04e-07, ValL: 9948.80 (R: 9703.91, KLD: 97.95)
# [INFO]   Fold 2/3 VAE E150/550, TrL: 10155.79 (R: 9824.07, KLD: 132.69), Beta: 2.500, LR: 1.04e-07, ValL: 9172.26 (R: 8923.91, KLD: 99.34)
# [INFO]   Fold 2/3 VAE E200/550, TrL: 9314.42 (R: 9199.23, KLD: 161.76), Beta: 0.712, LR: 1.04e-07, ValL: 8531.86 (R: 8439.03, KLD: 130.36)
# [INFO]   Fold 2/3 Early stopping VAE en epoch 209. Mejor val_loss: 8461.2302
# [INFO]   Fold 2/3 VAE final model loaded (best val_loss: 8461.2302).
# [INFO]   Fold 2/3 Modelo VAE guardado en: resultados_rfe_con_metadata/rfe_step_1_channel/fold_2/vae_model_fold_2.pt
# [INFO] Fold 2/3 Pool Train/Dev (Clasificador) (N=123):
#     ResearchGroup_Mapped:
#       AD: 64 (52.0%)
#       CN: 59 (48.0%)
#     Sex:
#       F: 62 (50.4%)
#       M: 61 (49.6%)
# [INFO]   Añadiendo metadatos al clasificador: ['Age', 'Sex']
# [INFO]   Forma final del set de entrenamiento del clasificador: (123, 514)
# [INFO]     --- Entrenando Clasificador: logreg ---
# [INFO] [SMOTE] ➜ Usando implementación de imblearn (CPU) para el clasificador 'logreg'.
# [INFO]       Mejores HPs para logreg: {'model__C': 0.028731536456492728}
# [INFO]       Modelo final (pipeline) para logreg listo.
# [INFO]       Resultados Fold 2 (logreg): AUC=0.7753, Bal.Acc=0.6866
# [INFO]       Pipeline completo de logreg del fold 2 guardado.
# [INFO]   Fold 2/3 completado en 106.27 segundos.
# [INFO] --- Iniciando Fold 3/3 ---
# [INFO] Fold 3/3 Test Set (Clasificador) (N=61):
#     ResearchGroup_Mapped:
#       AD: 32 (52.5%)
#       CN: 29 (47.5%)
#     Sex:
#       F: 30 (49.2%)
#       M: 31 (50.8%)
# [INFO] Fold 3/3 Pool Entrenamiento VAE (N=370):
#     ResearchGroup_Mapped:
#       AD: 63 (17.0%)
#       CN: 60 (16.2%)
#       MCI: 247 (66.8%)
#     Sex:
#       F: 176 (47.6%)
#       M: 194 (52.4%)
#     Age_Group:
#       0: 94 (25.4%)
#       1: 95 (25.7%)
#       2: 94 (25.4%)
#       3: 87 (23.5%)
# [INFO]   Fold 3/3 VAE val split será estratificado por ['ResearchGroup_Mapped', 'Sex', 'Age_Group'].
# [INFO] Fold 3/3 Actual Train Set (VAE) (N=296):
#     ResearchGroup_Mapped:
#       AD: 50 (16.9%)
#       CN: 49 (16.6%)
#       MCI: 197 (66.6%)
#     Sex:
#       F: 142 (48.0%)
#       M: 154 (52.0%)
#     Age_Group:
#       0: 76 (25.7%)
#       1: 76 (25.7%)
#       2: 75 (25.3%)
#       3: 69 (23.3%)
# [INFO] Fold 3/3 Internal Val Set (VAE) (N=74):
#     ResearchGroup_Mapped:
#       AD: 13 (17.6%)
#       CN: 11 (14.9%)
#       MCI: 50 (67.6%)
#     Sex:
#       F: 34 (45.9%)
#       M: 40 (54.1%)
#     Age_Group:
#       0: 18 (24.3%)
#       1: 19 (25.7%)
#       2: 19 (25.7%)
#       3: 18 (24.3%)
# [INFO]   Fold 3/3 Sujetos VAE actual train: 296, VAE internal val: 74
# [INFO] Aplicando normalización inter-canal (modo: zscore_offdiag) sobre 1 canales seleccionados.
# [INFO] Parámetros de normalización se calcularán usando 296 sujetos de entrenamiento.
# [INFO] Canal 'Pearson_Full_FisherZ_Signed': Off-diag zscore_offdiag (train_params: mean=-0.051, std=0.780)
# [INFO]   Fold 3/3 Usando dispositivo: cuda
# [INFO]   Fold 3/3 Usando scheduler: CosineAnnealingWarmRestarts (T_0=50)
# [INFO]   Fold 3/3 Entrenando VAE (Decoder: convtranspose, Encoder Layers: 4)...
# [INFO]   Fold 3/3 VAE E50/550, TrL: 13871.67 (R: 13329.28, KLD: 243.52), Beta: 2.227, LR: 1.04e-07, ValL: 12224.62 (R: 11532.95, KLD: 310.55)
# [INFO]   Fold 3/3 VAE E100/550, TrL: 11230.33 (R: 10905.52, KLD: 129.92), Beta: 2.500, LR: 1.04e-07, ValL: 9770.19 (R: 9473.73, KLD: 118.59)
# [INFO]   Fold 3/3 VAE E150/550, TrL: 10200.73 (R: 9875.03, KLD: 130.28), Beta: 2.500, LR: 1.04e-07, ValL: 9000.39 (R: 8714.53, KLD: 114.35)
# [INFO]   Fold 3/3 VAE E200/550, TrL: 9262.10 (R: 9146.99, KLD: 161.64), Beta: 0.712, LR: 1.04e-07, ValL: 8371.53 (R: 8269.37, KLD: 143.46)
# [INFO]   Fold 3/3 Early stopping VAE en epoch 211. Mejor val_loss: 8278.9253
# [INFO]   Fold 3/3 VAE final model loaded (best val_loss: 8278.9253).
# [INFO]   Fold 3/3 Modelo VAE guardado en: resultados_rfe_con_metadata/rfe_step_1_channel/fold_3/vae_model_fold_3.pt
# [INFO] Fold 3/3 Pool Train/Dev (Clasificador) (N=123):
#     ResearchGroup_Mapped:
#       AD: 63 (51.2%)
#       CN: 60 (48.8%)
#     Sex:
#       F: 62 (50.4%)
#       M: 61 (49.6%)
# [INFO]   Añadiendo metadatos al clasificador: ['Age', 'Sex']
# [INFO]   Forma final del set de entrenamiento del clasificador: (123, 514)
# [INFO]     --- Entrenando Clasificador: logreg ---
# [INFO] [SMOTE] ➜ Usando implementación de imblearn (CPU) para el clasificador 'logreg'.
# [INFO]       Mejores HPs para logreg: {'model__C': 0.007227794714917242}
# [INFO]       Modelo final (pipeline) para logreg listo.
# [INFO]       Resultados Fold 3 (logreg): AUC=0.6853, Bal.Acc=0.5900
# [INFO]       Pipeline completo de logreg del fold 3 guardado.
# [INFO]   Fold 3/3 completado en 105.87 segundos.
# [INFO]
# --- Resumen de Rendimiento para Clasificador: logreg (Promedio sobre Folds Externos) ---
# [INFO] Auc                 : 0.7549 +/- 0.0620
# [INFO] Pr_auc              : 0.7665 +/- 0.0556
# [INFO] Accuracy            : 0.6735 +/- 0.0770
# [INFO] Balanced_accuracy   : 0.6727 +/- 0.0768
# [INFO] Sensitivity         : 0.7167 +/- 0.1102
# [INFO] Specificity         : 0.6287 +/- 0.0911
# [INFO] F1_score            : 0.6926 +/- 0.0785
# [INFO] Resultados detallados de todos los clasificadores guardados en: resultados_rfe_con_metadata/rfe_step_1_channel/all_folds_metrics_MULTI_logreg_vaeconvtranspose4l_ld512_beta2.5_normzscore_offdiag_ch1sel_intFCquarter_drop0.2_ln0_outer3x1_scorebalanced_accuracy.csv
# [INFO] Sumario estadístico de métricas (por clasificador) guardado en: resultados_rfe_con_metadata/rfe_step_1_channel/summary_metrics_MULTI_logreg_vaeconvtranspose4l_ld512_beta2.5_normzscore_offdiag_ch1sel_intFCquarter_drop0.2_ln0_outer3x1_scorebalanced_accuracy.txt
# [INFO] Progreso final de RFE guardado en: resultados_rfe_con_metadata/rfe_summary.csv
# [INFO]
#
# --- RESULTADOS FINALES DEL ESTUDIO RFE ---
#    num_channels  balanced_accuracy                                                                                                                        channels_in_baseline
# 0             7           0.655371  DistanceCorr, Granger_F_lag1, MI_KNN_Symmetric, Pearson_Full_FisherZ_Signed, Pearson_OMST_GCE_Signed_Weighted, dFC_AbsDiffMean, dFC_StdDev
# 1             6           0.699088              DistanceCorr, Granger_F_lag1, MI_KNN_Symmetric, Pearson_Full_FisherZ_Signed, Pearson_OMST_GCE_Signed_Weighted, dFC_AbsDiffMean
# 2             5           0.697484                                                DistanceCorr, Granger_F_lag1, MI_KNN_Symmetric, Pearson_Full_FisherZ_Signed, dFC_AbsDiffMean
# 3             4           0.715253                                                                 DistanceCorr, Granger_F_lag1, MI_KNN_Symmetric, Pearson_Full_FisherZ_Signed
# 4             3           0.694814                                                                                 DistanceCorr, MI_KNN_Symmetric, Pearson_Full_FisherZ_Signed
# 5             2           0.718125                                                                                                   DistanceCorr, Pearson_Full_FisherZ_Signed
# 6             1           0.672735                                                                                                                 Pearson_Full_FisherZ_Signed
# [INFO]
# Resultados de RFE guardados en: resultados_rfe_con_metadata/rfe_summary.csv
# [INFO] Gráfica de RFE guardada en: resultados_rfe_con_metadata/rfe_channel_performance.png
